# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, GRU, Input, Flatten, Masking, merge, Reshape, Lambda, TimeDistributed, Dropout
from keras.layers.merge import Concatenate, Add
from keras import backend as K
from keras.optimizers import RMSprop, SGD, Adam
from keras.utils.data_utils import get_file
from keras.models import Model
import numpy as np
import random
import sys
import re

DROPOUT = 0.1
SENTENCE_BATCH_SIZE = 128
LSTM_WIDTH = 512
SENTENCE_START = '#'
SENTENCE_END = '_'

caps = "([A-Z])"
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co)"
starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
websites = "[.](com|net|org|io|gov)"

def split_into_sentences(text):
    text = " " + text + "  "
    text = text.replace("\n"," ")
    text = re.sub(prefixes,"\\1<prd>",text)
    text = re.sub(websites,"<prd>\\1",text)
    if "Ph.D" in text: text = text.replace("Ph.D.","Ph<prd>D<prd>")
    text = re.sub("\s" + caps + "[.] "," \\1<prd> ",text)
    text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
    text = re.sub(caps + "[.]" + caps + "[.]" + caps + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
    text = re.sub(caps + "[.]" + caps + "[.]","\\1<prd>\\2<prd>",text)
    text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
    text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
    text = re.sub(" " + caps + "[.]"," \\1<prd>",text)
    if "”" in text: text = text.replace(".”","”.")
    if "\"" in text: text = text.replace(".\"","\".")
    if "!" in text: text = text.replace("!\"","\"!")
    if "?" in text: text = text.replace("?\"","\"?")
    #if "\'" in text: text = text.replace("\'", " ")
    text = text.replace(". ","."+SENTENCE_END+"<stop> ")
    text = text.replace("? ","?"+SENTENCE_END+"<stop> ")
    text = text.replace("! ","!"+SENTENCE_END+"<stop> ")
    text = text.replace("<prd> ",".")
    sentences = text.split("<stop>")
    sentences = sentences[:-1]
    sentences = [s.strip() for s in sentences]
    out = []
    for s in sentences:
        if (len(s) > 30) and (len(s) < 500):
            out.append(SENTENCE_START+s)
    return out


path_shakespeare = get_file('shakespeare.txt', origin='http://norvig.com/ngrams/shakespeare.txt')
text_shakespeare = open(path_shakespeare).read()
text_shakespeare = text_shakespeare.lower().replace('\n', ' ').replace('=', ' ').replace(r"\\'", " ")
print('corpus length:', len(text_shakespeare))

# nltk.download()
#tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
#tokenized = tokenizer.tokenize(text)

sentences_shakespeare = np.array(split_into_sentences(text_shakespeare))
sentences_shakespeare = sorted(sentences_shakespeare, key=len)
chars = sorted(list(set("".join(sentences_shakespeare))))

print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

def text_generator(sentences):

    cum_count=0
    while 1:
        count=0
        cum_count += 1
        for i in range(0, len(sentences), SENTENCE_BATCH_SIZE): # len(sentences)
            print('batch number: ', count, ', cumulative batch number: ', cum_count)
            count += 1

            sentence_batch = sentences[i:i + SENTENCE_BATCH_SIZE]
            maxlen_batch = len(max(sentence_batch, key=len))

            X = np.zeros((SENTENCE_BATCH_SIZE, maxlen_batch, len(chars)), dtype=np.int32)
            y = np.zeros((SENTENCE_BATCH_SIZE, maxlen_batch, len(chars)), dtype=np.int32)
            w = np.zeros((SENTENCE_BATCH_SIZE, maxlen_batch), dtype=np.int32)

            for i, sentence in enumerate(sentence_batch):

                for t, char in enumerate(sentence):
                    X[i, t, char_indices[char]] = 1

                for t in range(len(sentence)-1):
                    taget_pos = t+1
                    y[i, t, char_indices[sentence[taget_pos]]] = 1
                    w[i, t] = 1

            yield ([X, X], y, w)



print('Build model...')


def concat_context(inputs):
    seq = inputs[0]
    c = inputs[1]
    c_tiled = K.tile(K.reshape(c, [-1, 1, 512]), (1,K.shape(seq)[1],1) )
    out = K.concatenate([seq, c_tiled], axis=2)

    boolean_mask = K.any(K.not_equal(seq, 0), axis=-1, keepdims=True)

    # K.print_tensor( out * K.cast(boolean_mask, K.floatx()) )

    return out * K.cast(boolean_mask, K.floatx())


def get_encoder(lstm_width, dropout):
    context_input = Input(shape=(None, len(chars)))
    x = Masking(mask_value=0)(context_input)
    x = GRU(lstm_width, return_sequences=True, go_backwards=True, dropout=dropout)(x)
    #xf = GRU(LSTM_WIDTH, return_sequences=True, go_backwards=False, dropout=0.0)(x)
    #x = Concatenate(axis=2)([xf, xb])
    x = GRU(lstm_width, return_sequences=True, dropout=dropout)(x)
    encoder_output = GRU(lstm_width, return_sequences=False, dropout=dropout)(x)
    
    return Model(inputs=[context_input], outputs=[encoder_output])    
    
    
def get_autoencoder(encoder, lstm_width, dropout):
    context_input = Input(shape=(None, len(chars)))
    encoder_output = encoder(context_input)
    #encoder_output = Reshape((1,lstm_width))(encoder_output)

    teacher_input = Input(shape=(None, len(chars)))
    decoder_input = Masking(mask_value=0)(teacher_input)

    context_layer1 = Lambda(concat_context)
    decoder_input_c = context_layer1([decoder_input, encoder_output])

    y1 = GRU(lstm_width, return_sequences=True, dropout=dropout)(decoder_input_c)
    y2 = GRU(lstm_width, return_sequences=True, dropout=dropout)(y1)
    y3 = GRU(lstm_width, return_sequences=True, dropout=dropout)(y2)

    context_layer2 = Lambda(concat_context)
    decoder_appended = context_layer2([y3, encoder_output])

    decoder_appended = TimeDistributed(Dense(lstm_width, activation='relu'))(decoder_appended)
    decoder_appended = TimeDistributed(Dropout(0.5))(decoder_appended)
    decoder_output = TimeDistributed(Dense(len(chars), activation='softmax'))(decoder_appended)

    return Model(inputs=[context_input, teacher_input], outputs=[decoder_output])

    
encoder = get_encoder(lstm_width=LSTM_WIDTH, dropout=DROPOUT)
shakespeare_autoencoder = get_autoencoder(encoder, lstm_width=LSTM_WIDTH, dropout=DROPOUT)

optimizer = Adam(clipnorm=1.0)
shakespeare_autoencoder.compile(loss='categorical_crossentropy', optimizer=optimizer, sample_weight_mode="temporal")


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


shakespeare_gen = text_generator(sentences_shakespeare)

for iteration in range(1, 100):
    print()
    print('-' * 50)
    print('Iteration', iteration)

    shakespeare_autoencoder.save('model_shakespeare.hd5')
    shakespeare_history = shakespeare_autoencoder.fit_generator(shakespeare_gen, 
                            steps_per_epoch=len(sentences_shakespeare)/SENTENCE_BATCH_SIZE-10, 
                            epochs=1, verbose=1, workers=1)

# Some simple test of model prediction performance
test_set = shakespeare_gen.__next__()
prediction = model.predict_on_batch(test_set[0])
for i in range(len(test_set[1])):

    sentence = np.argmax(test_set[0][0][i], axis=1)
    sentence_decode = ''
    for t in range(len(sentence)):
        sentence_decode += indices_char[sentence[t]]

    frag = np.argmax(test_set[0][1][i], axis=1)
    frag_decode = ''
    for t in range(len(frag)):
        frag_decode += indices_char[frag[t]]

    predicted_symbol = indices_char[np.argmax(prediction[i])]
    true_symbol = indices_char[np.argmax(test_set[1][i])]
    print('Sentence: ', sentence_decode)
    print('Frag: ', frag_decode, ' Predicted symbol: \"%s\"' % (predicted_symbol),
          ' True symbol: \"%s\"' % (true_symbol))
# Out:
# corpus length: 4538523
# total chars: 45
# Build model...
# --------------------------------------------------
# Iteration 1
# Epoch 1/1batch number:
#  0 , cumulative batch number:  1
# batch number:  1 , cumulative batch number:  1
# batch number:  2 , cumulative batch number:  1
# batch number:  3 , cumulative batch number:  1
# batch number:  4 , cumulative batch number:  1
# batch number:  5 , cumulative batch number:  1
# batch number:  6 , cumulative batch number:  1
# batch number:  7 , cumulative batch number:  1
# batch number:  8 , cumulative batch number:  1
# batch number:  9 , cumulative batch number:  1
# batch number:  10 , cumulative batch number:  1
#   1/288 [..............................] - ETA: 2557s - loss: 3.8073
# batch number:  11 , cumulative batch number:  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-a194a7010b38> in <module>()
#     186     shakespeare_history = shakespeare_autoencoder.fit_generator(shakespeare_gen,
#     187                             steps_per_epoch=len(sentences_shakespeare)/SENTENCE_BATCH_SIZE-10,
# --> 188                             epochs=1, verbose=1, workers=1)
#     189
#     190 # Some simple test of model prediction performance
#
# /home/boris/keras-environment/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /home/boris/keras-environment/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1875                     outs = self.train_on_batch(x, y,
#    1876                                                sample_weight=sample_weight,
# -> 1877                                                class_weight=class_weight)
#    1878
#    1879                     if not isinstance(outs, list):
#
# /home/boris/keras-environment/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1619             ins = x + y + sample_weights
#    1620         self._make_train_function()
# -> 1621         outputs = self.train_function(ins)
#    1622         if len(outputs) == 1:
#    1623             return outputs[0]
#
# /home/boris/keras-environment/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2117         session = get_session()
#    2118         updated = session.run(self.outputs + [self.updates_op],
# -> 2119                               feed_dict=feed_dict)
#    2120         return updated[:len(self.outputs)]
#    2121
#
# /home/boris/keras-environment/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/boris/keras-environment/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/boris/keras-environment/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/boris/keras-environment/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/boris/keras-environment/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
for iteration in range(1, 100):
    print()
    print('-' * 50)
    print('Iteration', iteration)

    model.save('model_shakespeare.hd5')
    model.fit_generator(shakespeare_gen, steps_per_epoch=len(sentences_shakespeare)/SENTENCE_BATCH_SIZE-10, epochs=1, verbose=1, workers=1)
# Out:
# --------------------------------------------------
# Iteration 1
# batch number:  171Epoch 1/1
#  , cumulative batch number:  57
# batch number:  172 , cumulative batch number:  57
# batch number:  173 , cumulative batch number:  57
# batch number:  174 , cumulative batch number:  57
# batch number:  175 , cumulative batch number:  57
# batch number:  176 , cumulative batch number:  57
# batch number:  177 , cumulative batch number:  57
# batch number:  178 , cumulative batch number:  57
# batch number:  179 , cumulative batch number:  57
# batch number:  180 , cumulative batch number:  57
# batch number:  181 , cumulative batch number:  57
#   1/587 [..............................] - ETA: 372s - loss: 1.5200batch number:  182 , cumulative batch number:  57
#   2/587 [..............................] - ETA: 364s - loss: 1.4034batch number:  183 , cumulative batch number:  57
#   3/587 [..............................] - ETA: 359s - loss: 1.2592batch number:  184 , cumulative batch number:  57
#   4/587 [..............................] - ETA: 357s - loss: 1.1051batch number:  185 , cumulative batch number:  57
#   5/587 [..............................] - ETA: 358s - loss: 0.9622batch number:  186 , cumulative batch number:  57
#   6/587 [..............................] - ETA: 358s - loss: 0.8387batch number:  187 , cumulative batch number:  57
#   7/587 [..............................] - ETA: 359s - loss: 0.7537batch number:  188 , cumulative batch number:  57
#   8/587 [..............................] - ETA: 360s - loss: 0.6984batch number:  189 , cumulative batch number:  57
#   9/587 [..............................] - ETA: 359s - loss: 0.6586batch number:  190 , cumulative batch number:  57
#  10/587 [..............................] - ETA: 358s - loss: 0.6244batch number:  191 , cumulative batch number:  57
#  11/587 [..............................] - ETA: 357s - loss: 0.5940batch number:  192 , cumulative batch number:  57
#  12/587 [..............................] - ETA: 358s - loss: 0.5675batch number:  193 , cumulative batch number:  57
#  13/587 [..............................] - ETA: 357s - loss: 0.5417batch number:  194 , cumulative batch number:  57
#  14/587 [..............................] - ETA: 357s - loss: 0.5168batch number:  195 , cumulative batch number:  57
#  15/587 [..............................] - ETA: 357s - loss: 0.4974batch number:  196 , cumulative batch number:  57
#  16/587 [..............................] - ETA: 356s - loss: 0.4784batch number:  197 , cumulative batch number:  57
#  17/587 [..............................] - ETA: 356s - loss: 0.4619batch number:  198 , cumulative batch number:  57
#  18/587 [..............................] - ETA: 356s - loss: 0.4465batch number:  199 , cumulative batch number:  57
#  19/587 [..............................] - ETA: 356s - loss: 0.4327batch number:  200 , cumulative batch number:  57
#  20/587 [>.............................] - ETA: 356s - loss: 0.4205batch number:  201 , cumulative batch number:  57
#  21/587 [>.............................] - ETA: 356s - loss: 0.4104batch number:  202 , cumulative batch number:  57
#  22/587 [>.............................] - ETA: 356s - loss: 0.3992batch number:  203 , cumulative batch number:  57
#  23/587 [>.............................] - ETA: 356s - loss: 0.3883batch number:  204 , cumulative batch number:  57
#  24/587 [>.............................] - ETA: 356s - loss: 0.3791batch number:  205 , cumulative batch number:  57
#  25/587 [>.............................] - ETA: 356s - loss: 0.3709batch number:  206 , cumulative batch number:  57
#  26/587 [>.............................] - ETA: 356s - loss: 0.3630batch number:  207 , cumulative batch number:  57
#  27/587 [>.............................] - ETA: 356s - loss: 0.3550batch number:  208 , cumulative batch number:  57
#  28/587 [>.............................] - ETA: 355s - loss: 0.3481batch number:  209 , cumulative batch number:  57
#  29/587 [>.............................] - ETA: 355s - loss: 0.3418batch number:  210 , cumulative batch number:  57
#  30/587 [>.............................] - ETA: 355s - loss: 0.3364batch number:  211 , cumulative batch number:  57
#  31/587 [>.............................] - ETA: 355s - loss: 0.3315batch number:  212 , cumulative batch number:  57
#  32/587 [>.............................] - ETA: 355s - loss: 0.3267batch number:  213 , cumulative batch number:  57
#  33/587 [>.............................] - ETA: 355s - loss: 0.3214batch number:  214 , cumulative batch number:  57
#  34/587 [>.............................] - ETA: 355s - loss: 0.3171batch number:  215 , cumulative batch number:  57
#  35/587 [>.............................] - ETA: 355s - loss: 0.3126batch number:  216 , cumulative batch number:  57
#  36/587 [>.............................] - ETA: 355s - loss: 0.3087batch number:  217 , cumulative batch number:  57
#  37/587 [>.............................] - ETA: 355s - loss: 0.3047batch number:  218 , cumulative batch number:  57
#  38/587 [>.............................] - ETA: 355s - loss: 0.3016batch number:  219 , cumulative batch number:  57
#  39/587 [>.............................] - ETA: 355s - loss: 0.2989batch number:  220 , cumulative batch number:  57
#  40/587 [=>............................] - ETA: 355s - loss: 0.2954batch number:  221 , cumulative batch number:  57
#  41/587 [=>............................] - ETA: 355s - loss: 0.2928batch number:  222 , cumulative batch number:  57
#  42/587 [=>............................] - ETA: 355s - loss: 0.2897batch number:  223 , cumulative batch number:  57
#  43/587 [=>............................] - ETA: 355s - loss: 0.2873batch number:  224 , cumulative batch number:  57
#  44/587 [=>............................] - ETA: 356s - loss: 0.2847batch number:  225 , cumulative batch number:  57
#  45/587 [=>............................] - ETA: 356s - loss: 0.2822batch number:  226 , cumulative batch number:  57
#  46/587 [=>............................] - ETA: 356s - loss: 0.2798batch number:  227 , cumulative batch number:  57
#  47/587 [=>............................] - ETA: 356s - loss: 0.2778batch number:  228 , cumulative batch number:  57
#  48/587 [=>............................] - ETA: 356s - loss: 0.2754batch number:  229 , cumulative batch number:  57
#  49/587 [=>............................] - ETA: 356s - loss: 0.2731batch number:  230 , cumulative batch number:  57
#  50/587 [=>............................] - ETA: 356s - loss: 0.2714batch number:  231 , cumulative batch number:  57
#  51/587 [=>............................] - ETA: 356s - loss: 0.2698batch number:  232 , cumulative batch number:  57
#  52/587 [=>............................] - ETA: 356s - loss: 0.2678batch number:  233 , cumulative batch number:  57
#  53/587 [=>............................] - ETA: 356s - loss: 0.2659batch number:  234 , cumulative batch number:  57
#  54/587 [=>............................] - ETA: 356s - loss: 0.2644batch number:  235 , cumulative batch number:  57
#  55/587 [=>............................] - ETA: 356s - loss: 0.2629batch number:  236 , cumulative batch number:  57
#  56/587 [=>............................] - ETA: 356s - loss: 0.2613batch number:  237 , cumulative batch number:  57
#  57/587 [=>............................] - ETA: 356s - loss: 0.2598batch number:  238 , cumulative batch number:  57
#  58/587 [=>............................] - ETA: 357s - loss: 0.2582batch number:  239 , cumulative batch number:  57
#  59/587 [==>...........................] - ETA: 357s - loss: 0.2570batch number:  240 , cumulative batch number:  57
#  60/587 [==>...........................] - ETA: 357s - loss: 0.2558batch number:  241 , cumulative batch number:  57
#  61/587 [==>...........................] - ETA: 357s - loss: 0.2545batch number:  242 , cumulative batch number:  57
#  62/587 [==>...........................] - ETA: 357s - loss: 0.2528batch number:  243 , cumulative batch number:  57
#  63/587 [==>...........................] - ETA: 357s - loss: 0.2518batch number:  244 , cumulative batch number:  57
#  64/587 [==>...........................] - ETA: 357s - loss: 0.2504batch number:  245 , cumulative batch number:  57
#  65/587 [==>...........................] - ETA: 357s - loss: 0.2492batch number:  246 , cumulative batch number:  57
#  66/587 [==>...........................] - ETA: 357s - loss: 0.2478batch number:  247 , cumulative batch number:  57
#  67/587 [==>...........................] - ETA: 357s - loss: 0.2467batch number:  248 , cumulative batch number:  57
#  68/587 [==>...........................] - ETA: 357s - loss: 0.2455batch number:  249 , cumulative batch number:  57
#  69/587 [==>...........................] - ETA: 357s - loss: 0.2447batch number:  250 , cumulative batch number:  57
#  70/587 [==>...........................] - ETA: 358s - loss: 0.2438batch number:  251 , cumulative batch number:  57
#  71/587 [==>...........................] - ETA: 358s - loss: 0.2428batch number:  252 , cumulative batch number:  57
#  72/587 [==>...........................] - ETA: 358s - loss: 0.2417batch number:  253 , cumulative batch number:  57
#  73/587 [==>...........................] - ETA: 358s - loss: 0.2411batch number:  254 , cumulative batch number:  57
#  74/587 [==>...........................] - ETA: 358s - loss: 0.2403batch number:  255 , cumulative batch number:  57
#  75/587 [==>...........................] - ETA: 358s - loss: 0.2393batch number:  256 , cumulative batch number:  57
#  76/587 [==>...........................] - ETA: 358s - loss: 0.2384batch number:  257 , cumulative batch number:  57
#  77/587 [==>...........................] - ETA: 358s - loss: 0.2377batch number:  258 , cumulative batch number:  57
#  78/587 [==>...........................] - ETA: 358s - loss: 0.2368batch number:  259 , cumulative batch number:  57
#  79/587 [===>..........................] - ETA: 358s - loss: 0.2363batch number:  260 , cumulative batch number:  57
#  80/587 [===>..........................] - ETA: 359s - loss: 0.2358batch number:  261 , cumulative batch number:  57
#  81/587 [===>..........................] - ETA: 359s - loss: 0.2350batch number:  262 , cumulative batch number:  57
#  82/587 [===>..........................] - ETA: 359s - loss: 0.2342batch number:  263 , cumulative batch number:  57
#  83/587 [===>..........................] - ETA: 359s - loss: 0.2333batch number:  264 , cumulative batch number:  57
#  84/587 [===>..........................] - ETA: 359s - loss: 0.2329batch number:  265 , cumulative batch number:  57
#  85/587 [===>..........................] - ETA: 359s - loss: 0.2321batch number:  266 , cumulative batch number:  57
#  86/587 [===>..........................] - ETA: 359s - loss: 0.2314batch number:  267 , cumulative batch number:  57
#  87/587 [===>..........................] - ETA: 359s - loss: 0.2307batch number:  268 , cumulative batch number:  57
#  88/587 [===>..........................] - ETA: 359s - loss: 0.2303batch number:  269 , cumulative batch number:  57
#  89/587 [===>..........................] - ETA: 359s - loss: 0.2298batch number:  270 , cumulative batch number:  57
#  90/587 [===>..........................] - ETA: 359s - loss: 0.2292batch number:  271 , cumulative batch number:  57
#  91/587 [===>..........................] - ETA: 359s - loss: 0.2287batch number:  272 , cumulative batch number:  57
#  92/587 [===>..........................] - ETA: 359s - loss: 0.2282batch number:  273 , cumulative batch number:  57
#  93/587 [===>..........................] - ETA: 359s - loss: 0.2281batch number:  274 , cumulative batch number:  57
#  94/587 [===>..........................] - ETA: 359s - loss: 0.2275batch number:  275 , cumulative batch number:  57
#  95/587 [===>..........................] - ETA: 359s - loss: 0.2271batch number:  276 , cumulative batch number:  57
#  96/587 [===>..........................] - ETA: 359s - loss: 0.2266batch number:  277 , cumulative batch number:  57
#  97/587 [===>..........................] - ETA: 359s - loss: 0.2264batch number:  278 , cumulative batch number:  57
#  98/587 [====>.........................] - ETA: 359s - loss: 0.2261batch number:  279 , cumulative batch number:  57
#  99/587 [====>.........................] - ETA: 359s - loss: 0.2257batch number:  280 , cumulative batch number:  57
# 100/587 [====>.........................] - ETA: 359s - loss: 0.2252batch number:  281 , cumulative batch number:  57
# 101/587 [====>.........................] - ETA: 359s - loss: 0.2249batch number:  282 , cumulative batch number:  57
# 102/587 [====>.........................] - ETA: 359s - loss: 0.2246batch number:  283 , cumulative batch number:  57
# 103/587 [====>.........................] - ETA: 359s - loss: 0.2244batch number:  284 , cumulative batch number:  57
# 104/587 [====>.........................] - ETA: 359s - loss: 0.2241batch number:  285 , cumulative batch number:  57
# 105/587 [====>.........................] - ETA: 360s - loss: 0.2240batch number:  286 , cumulative batch number:  57
# 106/587 [====>.........................] - ETA: 360s - loss: 0.2238batch number:  287 , cumulative batch number:  57
# 107/587 [====>.........................] - ETA: 360s - loss: 0.2237batch number:  288 , cumulative batch number:  57
# 108/587 [====>.........................] - ETA: 360s - loss: 0.2236batch number:  289 , cumulative batch number:  57
# 109/587 [====>.........................] - ETA: 360s - loss: 0.2235batch number:  290 , cumulative batch number:  57
# 110/587 [====>.........................] - ETA: 359s - loss: 0.2235batch number:  291 , cumulative batch number:  57
# 111/587 [====>.........................] - ETA: 359s - loss: 0.2234batch number:  292 , cumulative batch number:  57
# 112/587 [====>.........................] - ETA: 359s - loss: 0.2234batch number:  293 , cumulative batch number:  57
# 113/587 [====>.........................] - ETA: 359s - loss: 0.2233batch number:  294 , cumulative batch number:  57
# 114/587 [====>.........................] - ETA: 359s - loss: 0.2233batch number:  295 , cumulative batch number:  57
# 115/587 [====>.........................] - ETA: 359s - loss: 0.2232batch number:  296 , cumulative batch number:  57
# 116/587 [====>.........................] - ETA: 359s - loss: 0.2235batch number:  297 , cumulative batch number:  57
# 117/587 [====>.........................] - ETA: 359s - loss: 0.2236batch number:  298 , cumulative batch number:  57
# 118/587 [=====>........................] - ETA: 359s - loss: 0.2237batch number:  299 , cumulative batch number:  57
# 119/587 [=====>........................] - ETA: 359s - loss: 0.2239batch number:  300 , cumulative batch number:  57
# 120/587 [=====>........................] - ETA: 359s - loss: 0.2240batch number:  301 , cumulative batch number:  57
# 121/587 [=====>........................] - ETA: 359s - loss: 0.2240batch number:  302 , cumulative batch number:  57
# 122/587 [=====>........................] - ETA: 359s - loss: 0.2243batch number:  303 , cumulative batch number:  57
# 123/587 [=====>........................] - ETA: 359s - loss: 0.2244batch number:  304 , cumulative batch number:  57
# 124/587 [=====>........................] - ETA: 359s - loss: 0.2246batch number:  305 , cumulative batch number:  57
# 125/587 [=====>........................] - ETA: 359s - loss: 0.2248batch number:  306 , cumulative batch number:  57
# 126/587 [=====>........................] - ETA: 359s - loss: 0.2248batch number:  307 , cumulative batch number:  57
# 127/587 [=====>........................] - ETA: 359s - loss: 0.2248batch number:  308 , cumulative batch number:  57
# 128/587 [=====>........................] - ETA: 358s - loss: 0.2252batch number:  309 , cumulative batch number:  57
# 129/587 [=====>........................] - ETA: 358s - loss: 0.2254batch number:  310 , cumulative batch number:  57
# 130/587 [=====>........................] - ETA: 358s - loss: 0.2255batch number:  311 , cumulative batch number:  57
# 131/587 [=====>........................] - ETA: 358s - loss: 0.2256batch number:  312 , cumulative batch number:  57
# 132/587 [=====>........................] - ETA: 358s - loss: 0.2256batch number:  313 , cumulative batch number:  57
# 133/587 [=====>........................] - ETA: 358s - loss: 0.2256batch number:  314 , cumulative batch number:  57
# 134/587 [=====>........................] - ETA: 358s - loss: 0.2258batch number:  315 , cumulative batch number:  57
# 135/587 [=====>........................] - ETA: 358s - loss: 0.2260batch number:  316 , cumulative batch number:  57
# 136/587 [=====>........................] - ETA: 358s - loss: 0.2261batch number:  317 , cumulative batch number:  57
# 137/587 [=====>........................] - ETA: 357s - loss: 0.2263batch number:  318 , cumulative batch number:  57
# 138/587 [======>.......................] - ETA: 357s - loss: 0.2264batch number:  319 , cumulative batch number:  57
# 139/587 [======>.......................] - ETA: 357s - loss: 0.2266batch number:  320 , cumulative batch number:  57
# 140/587 [======>.......................] - ETA: 357s - loss: 0.2270batch number:  321 , cumulative batch number:  57
# 141/587 [======>.......................] - ETA: 357s - loss: 0.2274batch number:  322 , cumulative batch number:  57
# 142/587 [======>.......................] - ETA: 357s - loss: 0.2276batch number:  323 , cumulative batch number:  57
# 143/587 [======>.......................] - ETA: 357s - loss: 0.2280batch number:  324 , cumulative batch number:  57
# 144/587 [======>.......................] - ETA: 357s - loss: 0.2283batch number:  325 , cumulative batch number:  57
# 145/587 [======>.......................] - ETA: 356s - loss: 0.2285batch number:  326 , cumulative batch number:  57
# 146/587 [======>.......................] - ETA: 356s - loss: 0.2287batch number:  327 , cumulative batch number:  57
# 147/587 [======>.......................] - ETA: 356s - loss: 0.2289batch number:  328 , cumulative batch number:  57
# 148/587 [======>.......................] - ETA: 356s - loss: 0.2291batch number:  329 , cumulative batch number:  57
# 149/587 [======>.......................] - ETA: 356s - loss: 0.2297batch number:  330 , cumulative batch number:  57
# 150/587 [======>.......................] - ETA: 355s - loss: 0.2300batch number:  331 , cumulative batch number:  57
# 151/587 [======>.......................] - ETA: 355s - loss: 0.2302batch number:  332 , cumulative batch number:  57
# 152/587 [======>.......................] - ETA: 355s - loss: 0.2305batch number:  333 , cumulative batch number:  57
# 153/587 [======>.......................] - ETA: 355s - loss: 0.2308batch number:  334 , cumulative batch number:  57
# 154/587 [======>.......................] - ETA: 355s - loss: 0.2311batch number:  335 , cumulative batch number:  57
# 155/587 [======>.......................] - ETA: 355s - loss: 0.2313batch number:  336 , cumulative batch number:  57
# 156/587 [======>.......................] - ETA: 354s - loss: 0.2315batch number:  337 , cumulative batch number:  57
# 157/587 [=======>......................] - ETA: 354s - loss: 0.2318batch number:  338 , cumulative batch number:  57
# 158/587 [=======>......................] - ETA: 354s - loss: 0.2322batch number:  339 , cumulative batch number:  57
# 159/587 [=======>......................] - ETA: 354s - loss: 0.2324batch number:  340 , cumulative batch number:  57
# 160/587 [=======>......................] - ETA: 354s - loss: 0.2325batch number:  341 , cumulative batch number:  57
# 161/587 [=======>......................] - ETA: 353s - loss: 0.2329batch number:  342 , cumulative batch number:  57
# 162/587 [=======>......................] - ETA: 353s - loss: 0.2331batch number:  343 , cumulative batch number:  57
# 163/587 [=======>......................] - ETA: 353s - loss: 0.2334batch number:  344 , cumulative batch number:  57
# 164/587 [=======>......................] - ETA: 353s - loss: 0.2337batch number:  345 , cumulative batch number:  57
# 165/587 [=======>......................] - ETA: 352s - loss: 0.2340batch number:  346 , cumulative batch number:  57
# 166/587 [=======>......................] - ETA: 352s - loss: 0.2343batch number:  347 , cumulative batch number:  57
# 167/587 [=======>......................] - ETA: 352s - loss: 0.2344batch number:  348 , cumulative batch number:  57
# 168/587 [=======>......................] - ETA: 352s - loss: 0.2347batch number:  349 , cumulative batch number:  57
# 169/587 [=======>......................] - ETA: 351s - loss: 0.2352batch number:  350 , cumulative batch number:  57
# 170/587 [=======>......................] - ETA: 351s - loss: 0.2355batch number:  351 , cumulative batch number:  57
# 171/587 [=======>......................] - ETA: 351s - loss: 0.2357batch number:  352 , cumulative batch number:  57
# 172/587 [=======>......................] - ETA: 351s - loss: 0.2361batch number:  353 , cumulative batch number:  57
# 173/587 [=======>......................] - ETA: 350s - loss: 0.2364batch number:  354 , cumulative batch number:  57
# 174/587 [=======>......................] - ETA: 350s - loss: 0.2368batch number:  355 , cumulative batch number:  57
# 175/587 [=======>......................] - ETA: 350s - loss: 0.2371batch number:  356 , cumulative batch number:  57
# 176/587 [=======>......................] - ETA: 350s - loss: 0.2376batch number:  357 , cumulative batch number:  57
# 177/587 [========>.....................] - ETA: 349s - loss: 0.2380batch number:  358 , cumulative batch number:  57
# 178/587 [========>.....................] - ETA: 349s - loss: 0.2383batch number:  359 , cumulative batch number:  57
# 179/587 [========>.....................] - ETA: 349s - loss: 0.2386batch number:  360 , cumulative batch number:  57
# 180/587 [========>.....................] - ETA: 348s - loss: 0.2390batch number:  361 , cumulative batch number:  57
# 181/587 [========>.....................] - ETA: 348s - loss: 0.2393batch number:  362 , cumulative batch number:  57
# 182/587 [========>.....................] - ETA: 348s - loss: 0.2396batch number:  363 , cumulative batch number:  57
# 183/587 [========>.....................] - ETA: 347s - loss: 0.2400batch number:  364 , cumulative batch number:  57
# 184/587 [========>.....................] - ETA: 347s - loss: 0.2404batch number:  365 , cumulative batch number:  57
# 185/587 [========>.....................] - ETA: 347s - loss: 0.2407batch number:  366 , cumulative batch number:  57
# 186/587 [========>.....................] - ETA: 346s - loss: 0.2411batch number:  367 , cumulative batch number:  57
# 187/587 [========>.....................] - ETA: 346s - loss: 0.2413batch number:  368 , cumulative batch number:  57
# 188/587 [========>.....................] - ETA: 346s - loss: 0.2417batch number:  369 , cumulative batch number:  57
# 189/587 [========>.....................] - ETA: 346s - loss: 0.2420batch number:  370 , cumulative batch number:  57
# 190/587 [========>.....................] - ETA: 345s - loss: 0.2423batch number:  371 , cumulative batch number:  57
# 191/587 [========>.....................] - ETA: 345s - loss: 0.2426batch number:  372 , cumulative batch number:  57
# 192/587 [========>.....................] - ETA: 344s - loss: 0.2428batch number:  373 , cumulative batch number:  57
# 193/587 [========>.....................] - ETA: 344s - loss: 0.2432batch number:  374 , cumulative batch number:  57
# 194/587 [========>.....................] - ETA: 344s - loss: 0.2435batch number:  375 , cumulative batch number:  57
# 195/587 [========>.....................] - ETA: 343s - loss: 0.2439batch number:  376 , cumulative batch number:  57
# 196/587 [=========>....................] - ETA: 343s - loss: 0.2443batch number:  377 , cumulative batch number:  57
# 197/587 [=========>....................] - ETA: 343s - loss: 0.2446batch number:  378 , cumulative batch number:  57
# 198/587 [=========>....................] - ETA: 342s - loss: 0.2449batch number:  379 , cumulative batch number:  57
# 199/587 [=========>....................] - ETA: 342s - loss: 0.2453batch number:  380 , cumulative batch number:  57
# 200/587 [=========>....................] - ETA: 342s - loss: 0.2457batch number:  381 , cumulative batch number:  57
# 201/587 [=========>....................] - ETA: 341s - loss: 0.2461batch number:  382 , cumulative batch number:  57
# 202/587 [=========>....................] - ETA: 341s - loss: 0.2464batch number:  383 , cumulative batch number:  57
# 203/587 [=========>....................] - ETA: 341s - loss: 0.2470batch number:  384 , cumulative batch number:  57
# 204/587 [=========>....................] - ETA: 340s - loss: 0.2474batch number:  385 , cumulative batch number:  57
# 205/587 [=========>....................] - ETA: 340s - loss: 0.2478batch number:  386 , cumulative batch number:  57
# 206/587 [=========>....................] - ETA: 340s - loss: 0.2482batch number:  387 , cumulative batch number:  57
# 207/587 [=========>....................] - ETA: 339s - loss: 0.2487batch number:  388 , cumulative batch number:  57
# 208/587 [=========>....................] - ETA: 339s - loss: 0.2491batch number:  389 , cumulative batch number:  57
# 209/587 [=========>....................] - ETA: 338s - loss: 0.2495batch number:  390 , cumulative batch number:  57
# 210/587 [=========>....................] - ETA: 338s - loss: 0.2501batch number:  391 , cumulative batch number:  57
# 211/587 [=========>....................] - ETA: 338s - loss: 0.2507batch number:  392 , cumulative batch number:  57
# 212/587 [=========>....................] - ETA: 337s - loss: 0.2511batch number:  393 , cumulative batch number:  57
# 213/587 [=========>....................] - ETA: 337s - loss: 0.2516batch number:  394 , cumulative batch number:  57
# 214/587 [=========>....................] - ETA: 337s - loss: 0.2521batch number:  395 , cumulative batch number:  57
# 215/587 [=========>....................] - ETA: 336s - loss: 0.2526batch number:  396 , cumulative batch number:  57
# 216/587 [==========>...................] - ETA: 336s - loss: 0.2530batch number:  397 , cumulative batch number:  57
# 217/587 [==========>...................] - ETA: 336s - loss: 0.2534batch number:  398 , cumulative batch number:  57
# 218/587 [==========>...................] - ETA: 335s - loss: 0.2541batch number:  399 , cumulative batch number:  57
# 219/587 [==========>...................] - ETA: 335s - loss: 0.2545batch number:  400 , cumulative batch number:  57
# 220/587 [==========>...................] - ETA: 334s - loss: 0.2551batch number:  401 , cumulative batch number:  57
# 221/587 [==========>...................] - ETA: 334s - loss: 0.2557batch number:  402 , cumulative batch number:  57
# 222/587 [==========>...................] - ETA: 334s - loss: 0.2562batch number:  403 , cumulative batch number:  57
# 223/587 [==========>...................] - ETA: 333s - loss: 0.2568batch number:  404 , cumulative batch number:  57
# 224/587 [==========>...................] - ETA: 333s - loss: 0.2575batch number:  405 , cumulative batch number:  57
# 225/587 [==========>...................] - ETA: 333s - loss: 0.2580batch number:  406 , cumulative batch number:  57
# 226/587 [==========>...................] - ETA: 332s - loss: 0.2585batch number:  407 , cumulative batch number:  57
# 227/587 [==========>...................] - ETA: 332s - loss: 0.2590batch number:  408 , cumulative batch number:  57
# 228/587 [==========>...................] - ETA: 332s - loss: 0.2596batch number:  409 , cumulative batch number:  57
# 229/587 [==========>...................] - ETA: 331s - loss: 0.2601batch number:  410 , cumulative batch number:  57
# 230/587 [==========>...................] - ETA: 331s - loss: 0.2608batch number:  411 , cumulative batch number:  57
# 231/587 [==========>...................] - ETA: 331s - loss: 0.2614batch number:  412 , cumulative batch number:  57
# 232/587 [==========>...................] - ETA: 330s - loss: 0.2620batch number:  413 , cumulative batch number:  57
# 233/587 [==========>...................] - ETA: 330s - loss: 0.2626batch number:  414 , cumulative batch number:  57
# 234/587 [==========>...................] - ETA: 330s - loss: 0.2631batch number:  415 , cumulative batch number:  57
# 235/587 [==========>...................] - ETA: 329s - loss: 0.2637batch number:  416 , cumulative batch number:  57
# 236/587 [===========>..................] - ETA: 329s - loss: 0.2643batch number:  417 , cumulative batch number:  57
# 237/587 [===========>..................] - ETA: 329s - loss: 0.2649batch number:  418 , cumulative batch number:  57
# 238/587 [===========>..................] - ETA: 328s - loss: 0.2657batch number:  419 , cumulative batch number:  57
# 239/587 [===========>..................] - ETA: 328s - loss: 0.2664batch number:  420 , cumulative batch number:  57
# 240/587 [===========>..................] - ETA: 328s - loss: 0.2670batch number:  421 , cumulative batch number:  57
# 241/587 [===========>..................] - ETA: 327s - loss: 0.2677batch number:  422 , cumulative batch number:  57
# 242/587 [===========>..................] - ETA: 327s - loss: 0.2685batch number:  423 , cumulative batch number:  57
# 243/587 [===========>..................] - ETA: 327s - loss: 0.2693batch number:  424 , cumulative batch number:  57
# 244/587 [===========>..................] - ETA: 326s - loss: 0.2701batch number:  425 , cumulative batch number:  57
# 245/587 [===========>..................] - ETA: 326s - loss: 0.2709batch number:  426 , cumulative batch number:  57
# 246/587 [===========>..................] - ETA: 326s - loss: 0.2715batch number:  427 , cumulative batch number:  57
# 247/587 [===========>..................] - ETA: 325s - loss: 0.2723batch number:  428 , cumulative batch number:  57
# 248/587 [===========>..................] - ETA: 325s - loss: 0.2732batch number:  429 , cumulative batch number:  57
# 249/587 [===========>..................] - ETA: 325s - loss: 0.2741batch number:  430 , cumulative batch number:  57
# 250/587 [===========>..................] - ETA: 324s - loss: 0.2750batch number:  431 , cumulative batch number:  57
# 251/587 [===========>..................] - ETA: 324s - loss: 0.2758batch number:  432 , cumulative batch number:  57
# 252/587 [===========>..................] - ETA: 324s - loss: 0.2767batch number:  433 , cumulative batch number:  57
# 253/587 [===========>..................] - ETA: 323s - loss: 0.2775batch number:  434 , cumulative batch number:  57
# 254/587 [===========>..................] - ETA: 323s - loss: 0.2784batch number:  435 , cumulative batch number:  57
# 255/587 [============>.................] - ETA: 323s - loss: 0.2792batch number:  436 , cumulative batch number:  57
# 256/587 [============>.................] - ETA: 322s - loss: 0.2800batch number:  437 , cumulative batch number:  57
# 257/587 [============>.................] - ETA: 322s - loss: 0.2809batch number:  438 , cumulative batch number:  57
# 258/587 [============>.................] - ETA: 322s - loss: 0.2817batch number:  439 , cumulative batch number:  57
# 259/587 [============>.................] - ETA: 321s - loss: 0.2827batch number:  440 , cumulative batch number:  57
# 260/587 [============>.................] - ETA: 321s - loss: 0.2835batch number:  441 , cumulative batch number:  57
# 261/587 [============>.................] - ETA: 321s - loss: 0.2843batch number:  442 , cumulative batch number:  57
# 262/587 [============>.................] - ETA: 320s - loss: 0.2850batch number:  443 , cumulative batch number:  57
# 263/587 [============>.................] - ETA: 320s - loss: 0.2859batch number:  444 , cumulative batch number:  57
# 264/587 [============>.................] - ETA: 320s - loss: 0.2870batch number:  445 , cumulative batch number:  57
# 265/587 [============>.................] - ETA: 319s - loss: 0.2879batch number:  446 , cumulative batch number:  57
# 266/587 [============>.................] - ETA: 319s - loss: 0.2887batch number:  447 , cumulative batch number:  57
# 267/587 [============>.................] - ETA: 319s - loss: 0.2896batch number:  448 , cumulative batch number:  57
# 268/587 [============>.................] - ETA: 318s - loss: 0.2904batch number:  449 , cumulative batch number:  57
# 269/587 [============>.................] - ETA: 318s - loss: 0.2912batch number:  450 , cumulative batch number:  57
# 270/587 [============>.................] - ETA: 318s - loss: 0.2921batch number:  451 , cumulative batch number:  57
# 271/587 [============>.................] - ETA: 317s - loss: 0.2929batch number:  452 , cumulative batch number:  57
# 272/587 [============>.................] - ETA: 317s - loss: 0.2939batch number:  453 , cumulative batch number:  57
# 273/587 [============>.................] - ETA: 316s - loss: 0.2947batch number:  454 , cumulative batch number:  57
# 274/587 [============>.................] - ETA: 316s - loss: 0.2955batch number:  455 , cumulative batch number:  57
# 275/587 [=============>................] - ETA: 316s - loss: 0.2963batch number:  456 , cumulative batch number:  57
# 276/587 [=============>................] - ETA: 315s - loss: 0.2972batch number:  457 , cumulative batch number:  57
# 277/587 [=============>................] - ETA: 315s - loss: 0.2980batch number:  458 , cumulative batch number:  57
# 278/587 [=============>................] - ETA: 315s - loss: 0.2988batch number:  459 , cumulative batch number:  57
# 279/587 [=============>................] - ETA: 314s - loss: 0.2996batch number:  460 , cumulative batch number:  57
# 280/587 [=============>................] - ETA: 314s - loss: 0.3004batch number:  461 , cumulative batch number:  57
# 281/587 [=============>................] - ETA: 313s - loss: 0.3012batch number:  462 , cumulative batch number:  57
# 282/587 [=============>................] - ETA: 313s - loss: 0.3020batch number:  463 , cumulative batch number:  57
# 283/587 [=============>................] - ETA: 313s - loss: 0.3029batch number:  464 , cumulative batch number:  57
# 284/587 [=============>................] - ETA: 312s - loss: 0.3037batch number:  465 , cumulative batch number:  57
# 285/587 [=============>................] - ETA: 312s - loss: 0.3046batch number:  466 , cumulative batch number:  57
# 286/587 [=============>................] - ETA: 311s - loss: 0.3054batch number:  467 , cumulative batch number:  57
# 287/587 [=============>................] - ETA: 311s - loss: 0.3062batch number:  468 , cumulative batch number:  57
# 288/587 [=============>................] - ETA: 311s - loss: 0.3070batch number:  469 , cumulative batch number:  57
# 289/587 [=============>................] - ETA: 310s - loss: 0.3078batch number:  470 , cumulative batch number:  57
# 290/587 [=============>................] - ETA: 310s - loss: 0.3087batch number:  471 , cumulative batch number:  57
# 291/587 [=============>................] - ETA: 309s - loss: 0.3096batch number:  472 , cumulative batch number:  57
# 292/587 [=============>................] - ETA: 309s - loss: 0.3105batch number:  473 , cumulative batch number:  57
# 293/587 [=============>................] - ETA: 308s - loss: 0.3112batch number:  474 , cumulative batch number:  57
# 294/587 [==============>...............] - ETA: 308s - loss: 0.3120batch number:  475 , cumulative batch number:  57
# 295/587 [==============>...............] - ETA: 308s - loss: 0.3128batch number:  476 , cumulative batch number:  57
# 296/587 [==============>...............] - ETA: 307s - loss: 0.3137batch number:  477 , cumulative batch number:  57
# 297/587 [==============>...............] - ETA: 307s - loss: 0.3145batch number:  478 , cumulative batch number:  57
# 298/587 [==============>...............] - ETA: 306s - loss: 0.3153batch number:  479 , cumulative batch number:  57
# 299/587 [==============>...............] - ETA: 306s - loss: 0.3161batch number:  480 , cumulative batch number:  57
# 300/587 [==============>...............] - ETA: 305s - loss: 0.3168batch number:  481 , cumulative batch number:  57
# 301/587 [==============>...............] - ETA: 305s - loss: 0.3177batch number:  482 , cumulative batch number:  57
# 302/587 [==============>...............] - ETA: 305s - loss: 0.3186batch number:  483 , cumulative batch number:  57
# 303/587 [==============>...............] - ETA: 304s - loss: 0.3195batch number:  484 , cumulative batch number:  57
# 304/587 [==============>...............] - ETA: 304s - loss: 0.3202batch number:  485 , cumulative batch number:  57
# 305/587 [==============>...............] - ETA: 303s - loss: 0.3210batch number:  486 , cumulative batch number:  57
# 306/587 [==============>...............] - ETA: 303s - loss: 0.3219batch number:  487 , cumulative batch number:  57
# 307/587 [==============>...............] - ETA: 302s - loss: 0.3228batch number:  488 , cumulative batch number:  57
# 308/587 [==============>...............] - ETA: 302s - loss: 0.3237batch number:  489 , cumulative batch number:  57
# 309/587 [==============>...............] - ETA: 302s - loss: 0.3245batch number:  490 , cumulative batch number:  57
# 310/587 [==============>...............] - ETA: 301s - loss: 0.3253batch number:  491 , cumulative batch number:  57
# 311/587 [==============>...............] - ETA: 301s - loss: 0.3262batch number:  492 , cumulative batch number:  57
# 312/587 [==============>...............] - ETA: 300s - loss: 0.3271batch number:  493 , cumulative batch number:  57
# 313/587 [==============>...............] - ETA: 300s - loss: 0.3281batch number:  494 , cumulative batch number:  57
# 314/587 [===============>..............] - ETA: 299s - loss: 0.3290batch number:  495 , cumulative batch number:  57
# 315/587 [===============>..............] - ETA: 299s - loss: 0.3299batch number:  496 , cumulative batch number:  57
# 316/587 [===============>..............] - ETA: 299s - loss: 0.3309batch number:  497 , cumulative batch number:  57
# 317/587 [===============>..............] - ETA: 298s - loss: 0.3318batch number:  498 , cumulative batch number:  57
# 318/587 [===============>..............] - ETA: 298s - loss: 0.3327batch number:  499 , cumulative batch number:  57
# 319/587 [===============>..............] - ETA: 297s - loss: 0.3335batch number:  500 , cumulative batch number:  57
# 320/587 [===============>..............] - ETA: 297s - loss: 0.3346batch number:  501 , cumulative batch number:  57
# 321/587 [===============>..............] - ETA: 296s - loss: 0.3356batch number:  502 , cumulative batch number:  57
# 322/587 [===============>..............] - ETA: 296s - loss: 0.3365batch number:  503 , cumulative batch number:  57
# 323/587 [===============>..............] - ETA: 295s - loss: 0.3375batch number:  504 , cumulative batch number:  57
# 324/587 [===============>..............] - ETA: 295s - loss: 0.3385batch number:  505 , cumulative batch number:  57
# 325/587 [===============>..............] - ETA: 295s - loss: 0.3395batch number:  506 , cumulative batch number:  57
# 326/587 [===============>..............] - ETA: 294s - loss: 0.3404batch number:  507 , cumulative batch number:  57
# 327/587 [===============>..............] - ETA: 294s - loss: 0.3415batch number:  508 , cumulative batch number:  57
# 328/587 [===============>..............] - ETA: 293s - loss: 0.3424batch number:  509 , cumulative batch number:  57
# 329/587 [===============>..............] - ETA: 293s - loss: 0.3435batch number:  510 , cumulative batch number:  57
# 330/587 [===============>..............] - ETA: 292s - loss: 0.3445batch number:  511 , cumulative batch number:  57
# 331/587 [===============>..............] - ETA: 292s - loss: 0.3455batch number:  512 , cumulative batch number:  57
# 332/587 [===============>..............] - ETA: 292s - loss: 0.3464batch number:  513 , cumulative batch number:  57
# 333/587 [===============>..............] - ETA: 291s - loss: 0.3474batch number:  514 , cumulative batch number:  57
# 334/587 [================>.............] - ETA: 291s - loss: 0.3484batch number:  515 , cumulative batch number:  57
# 335/587 [================>.............] - ETA: 290s - loss: 0.3494batch number:  516 , cumulative batch number:  57
# 336/587 [================>.............] - ETA: 290s - loss: 0.3505batch number:  517 , cumulative batch number:  57
# 337/587 [================>.............] - ETA: 289s - loss: 0.3515batch number:  518 , cumulative batch number:  57
# 338/587 [================>.............] - ETA: 289s - loss: 0.3524batch number:  519 , cumulative batch number:  57
# 339/587 [================>.............] - ETA: 288s - loss: 0.3535batch number:  520 , cumulative batch number:  57
# 340/587 [================>.............] - ETA: 288s - loss: 0.3546batch number:  521 , cumulative batch number:  57
# 341/587 [================>.............] - ETA: 287s - loss: 0.3558batch number:  522 , cumulative batch number:  57
# 342/587 [================>.............] - ETA: 287s - loss: 0.3567batch number:  523 , cumulative batch number:  57
# 343/587 [================>.............] - ETA: 286s - loss: 0.3577batch number:  524 , cumulative batch number:  57
# 344/587 [================>.............] - ETA: 286s - loss: 0.3587batch number:  525 , cumulative batch number:  57
# 345/587 [================>.............] - ETA: 285s - loss: 0.3598batch number:  526 , cumulative batch number:  57
# 346/587 [================>.............] - ETA: 285s - loss: 0.3608batch number:  527 , cumulative batch number:  57
# 347/587 [================>.............] - ETA: 284s - loss: 0.3617batch number:  528 , cumulative batch number:  57
# 348/587 [================>.............] - ETA: 284s - loss: 0.3627batch number:  529 , cumulative batch number:  57
# 349/587 [================>.............] - ETA: 283s - loss: 0.3637batch number:  530 , cumulative batch number:  57
# 350/587 [================>.............] - ETA: 283s - loss: 0.3647batch number:  531 , cumulative batch number:  57
# 351/587 [================>.............] - ETA: 282s - loss: 0.3657batch number:  532 , cumulative batch number:  57
# 352/587 [================>.............] - ETA: 282s - loss: 0.3667batch number:  533 , cumulative batch number:  57
# 353/587 [=================>............] - ETA: 281s - loss: 0.3678batch number:  534 , cumulative batch number:  57
# 354/587 [=================>............] - ETA: 281s - loss: 0.3689batch number:  535 , cumulative batch number:  57
# 355/587 [=================>............] - ETA: 280s - loss: 0.3699batch number:  536 , cumulative batch number:  57
# 356/587 [=================>............] - ETA: 280s - loss: 0.3710batch number:  537 , cumulative batch number:  57
# 357/587 [=================>............] - ETA: 279s - loss: 0.3721batch number:  538 , cumulative batch number:  57
# 358/587 [=================>............] - ETA: 279s - loss: 0.3732batch number:  539 , cumulative batch number:  57
# 359/587 [=================>............] - ETA: 279s - loss: 0.3743batch number:  540 , cumulative batch number:  57
# 360/587 [=================>............] - ETA: 278s - loss: 0.3753batch number:  541 , cumulative batch number:  57
# 361/587 [=================>............] - ETA: 278s - loss: 0.3764batch number:  542 , cumulative batch number:  57
# 362/587 [=================>............] - ETA: 277s - loss: 0.3775batch number:  543 , cumulative batch number:  57
# 363/587 [=================>............] - ETA: 277s - loss: 0.3787batch number:  544 , cumulative batch number:  57
# 364/587 [=================>............] - ETA: 276s - loss: 0.3798batch number:  545 , cumulative batch number:  57
# 365/587 [=================>............] - ETA: 276s - loss: 0.3808batch number:  546 , cumulative batch number:  57
# 366/587 [=================>............] - ETA: 275s - loss: 0.3820batch number:  547 , cumulative batch number:  57
# 367/587 [=================>............] - ETA: 275s - loss: 0.3831batch number:  548 , cumulative batch number:  57
# 368/587 [=================>............] - ETA: 274s - loss: 0.3843batch number:  549 , cumulative batch number:  57
# 369/587 [=================>............] - ETA: 274s - loss: 0.3854batch number:  550 , cumulative batch number:  57
# 370/587 [=================>............] - ETA: 273s - loss: 0.3865batch number:  551 , cumulative batch number:  57
# 371/587 [=================>............] - ETA: 273s - loss: 0.3876batch number:  552 , cumulative batch number:  57
# 372/587 [=================>............] - ETA: 272s - loss: 0.3887batch number:  553 , cumulative batch number:  57
# 373/587 [==================>...........] - ETA: 272s - loss: 0.3899batch number:  554 , cumulative batch number:  57
# 374/587 [==================>...........] - ETA: 271s - loss: 0.3910batch number:  555 , cumulative batch number:  57
# 375/587 [==================>...........] - ETA: 271s - loss: 0.3921batch number:  556 , cumulative batch number:  57
# 376/587 [==================>...........] - ETA: 270s - loss: 0.3932batch number:  557 , cumulative batch number:  57
# 377/587 [==================>...........] - ETA: 270s - loss: 0.3943batch number:  558 , cumulative batch number:  57
# 378/587 [==================>...........] - ETA: 269s - loss: 0.3955batch number:  559 , cumulative batch number:  57
# 379/587 [==================>...........] - ETA: 269s - loss: 0.3967batch number:  560 , cumulative batch number:  57
# 380/587 [==================>...........] - ETA: 268s - loss: 0.3978batch number:  561 , cumulative batch number:  57
# 381/587 [==================>...........] - ETA: 268s - loss: 0.3988batch number:  562 , cumulative batch number:  57
# 382/587 [==================>...........] - ETA: 267s - loss: 0.4001batch number:  563 , cumulative batch number:  57
# 383/587 [==================>...........] - ETA: 267s - loss: 0.4013batch number:  564 , cumulative batch number:  57
# 384/587 [==================>...........] - ETA: 266s - loss: 0.4025batch number:  565 , cumulative batch number:  57
# 385/587 [==================>...........] - ETA: 266s - loss: 0.4037batch number:  566 , cumulative batch number:  57
# 386/587 [==================>...........] - ETA: 265s - loss: 0.4049batch number:  567 , cumulative batch number:  57
# 387/587 [==================>...........] - ETA: 265s - loss: 0.4062batch number:  568 , cumulative batch number:  57
# 388/587 [==================>...........] - ETA: 264s - loss: 0.4075batch number:  569 , cumulative batch number:  57
# 389/587 [==================>...........] - ETA: 264s - loss: 0.4087batch number:  570 , cumulative batch number:  57
# 390/587 [==================>...........] - ETA: 263s - loss: 0.4099batch number:  571 , cumulative batch number:  57
# 391/587 [==================>...........] - ETA: 263s - loss: 0.4111batch number:  572 , cumulative batch number:  57
# 392/587 [===================>..........] - ETA: 262s - loss: 0.4124batch number:  573 , cumulative batch number:  57
# 393/587 [===================>..........] - ETA: 262s - loss: 0.4137batch number:  574 , cumulative batch number:  57
# 394/587 [===================>..........] - ETA: 262s - loss: 0.4150batch number:  575 , cumulative batch number:  57
# 395/587 [===================>..........] - ETA: 261s - loss: 0.4163batch number:  576 , cumulative batch number:  57
# 396/587 [===================>..........] - ETA: 261s - loss: 0.4175batch number:  577 , cumulative batch number:  57
# 397/587 [===================>..........] - ETA: 260s - loss: 0.4188batch number:  578 , cumulative batch number:  57
# 398/587 [===================>..........] - ETA: 260s - loss: 0.4201batch number:  579 , cumulative batch number:  57
# 399/587 [===================>..........] - ETA: 259s - loss: 0.4214batch number:  580 , cumulative batch number:  57
# 400/587 [===================>..........] - ETA: 259s - loss: 0.4228batch number:  581 , cumulative batch number:  57
# 401/587 [===================>..........] - ETA: 258s - loss: 0.4242batch number:  582 , cumulative batch number:  57
# 402/587 [===================>..........] - ETA: 258s - loss: 0.4256batch number:  583 , cumulative batch number:  57
# 403/587 [===================>..........] - ETA: 258s - loss: 0.4270batch number:  584 , cumulative batch number:  57
# 404/587 [===================>..........] - ETA: 257s - loss: 0.4283batch number:  585 , cumulative batch number:  57
# ...
# 272/587 [============>.................] - ETA: 317s - loss: 0.2656batch number:  453 , cumulative batch number:  58
# 273/587 [============>.................] - ETA: 317s - loss: 0.2665batch number:  454 , cumulative batch number:  58
# 274/587 [============>.................] - ETA: 317s - loss: 0.2674batch number:  455 , cumulative batch number:  58
# 275/587 [=============>................] - ETA: 316s - loss: 0.2682batch number:  456 , cumulative batch number:  58
# 276/587 [=============>................] - ETA: 316s - loss: 0.2692batch number:  457 , cumulative batch number:  58
# 277/587 [=============>................] - ETA: 315s - loss: 0.2701batch number:  458 , cumulative batch number:  58
# 278/587 [=============>................] - ETA: 315s - loss: 0.2710batch number:  459 , cumulative batch number:  58
# 279/587 [=============>................] - ETA: 315s - loss: 0.2720batch number:  460 , cumulative batch number:  58
# 280/587 [=============>................] - ETA: 314s - loss: 0.2729batch number:  461 , cumulative batch number:  58
# 281/587 [=============>................] - ETA: 314s - loss: 0.2738batch number:  462 , cumulative batch number:  58
# 282/587 [=============>................] - ETA: 313s - loss: 0.2747batch number:  463 , cumulative batch number:  58
# 283/587 [=============>................] - ETA: 313s - loss: 0.2756batch number:  464 , cumulative batch number:  58
# 284/587 [=============>................] - ETA: 313s - loss: 0.2764batch number:  465 , cumulative batch number:  58
# 285/587 [=============>................] - ETA: 312s - loss: 0.2773batch number:  466 , cumulative batch number:  58
# 286/587 [=============>................] - ETA: 312s - loss: 0.2782batch number:  467 , cumulative batch number:  58
# 287/587 [=============>................] - ETA: 311s - loss: 0.2790batch number:  468 , cumulative batch number:  58
# 288/587 [=============>................] - ETA: 311s - loss: 0.2799batch number:  469 , cumulative batch number:  58
# 289/587 [=============>................] - ETA: 311s - loss: 0.2808batch number:  470 , cumulative batch number:  58
# 290/587 [=============>................] - ETA: 310s - loss: 0.2818batch number:  471 , cumulative batch number:  58
# 291/587 [=============>................] - ETA: 310s - loss: 0.2827batch number:  472 , cumulative batch number:  58
# 292/587 [=============>................] - ETA: 309s - loss: 0.2837batch number:  473 , cumulative batch number:  58
# 293/587 [=============>................] - ETA: 309s - loss: 0.2845batch number:  474 , cumulative batch number:  58
# 294/587 [==============>...............] - ETA: 309s - loss: 0.2853batch number:  475 , cumulative batch number:  58
# 295/587 [==============>...............] - ETA: 308s - loss: 0.2862batch number:  476 , cumulative batch number:  58
# 296/587 [==============>...............] - ETA: 308s - loss: 0.2872batch number:  477 , cumulative batch number:  58
# 297/587 [==============>...............] - ETA: 307s - loss: 0.2880batch number:  478 , cumulative batch number:  58
# 298/587 [==============>...............] - ETA: 307s - loss: 0.2890batch number:  479 , cumulative batch number:  58
# 299/587 [==============>...............] - ETA: 306s - loss: 0.2899batch number:  480 , cumulative batch number:  58
# 300/587 [==============>...............] - ETA: 306s - loss: 0.2907batch number:  481 , cumulative batch number:  58
# 301/587 [==============>...............] - ETA: 305s - loss: 0.2917batch number:  482 , cumulative batch number:  58
# 302/587 [==============>...............] - ETA: 305s - loss: 0.2926batch number:  483 , cumulative batch number:  58
# 303/587 [==============>...............] - ETA: 305s - loss: 0.2934batch number:  484 , cumulative batch number:  58
# 304/587 [==============>...............] - ETA: 304s - loss: 0.2943batch number:  485 , cumulative batch number:  58
# 305/587 [==============>...............] - ETA: 304s - loss: 0.2951batch number:  486 , cumulative batch number:  58
# 306/587 [==============>...............] - ETA: 303s - loss: 0.2961batch number:  487 , cumulative batch number:  58
# 307/587 [==============>...............] - ETA: 303s - loss: 0.2970batch number:  488 , cumulative batch number:  58
# 308/587 [==============>...............] - ETA: 302s - loss: 0.2980batch number:  489 , cumulative batch number:  58
# 309/587 [==============>...............] - ETA: 302s - loss: 0.2989batch number:  490 , cumulative batch number:  58
# 310/587 [==============>...............] - ETA: 302s - loss: 0.2998batch number:  491 , cumulative batch number:  58
# 311/587 [==============>...............] - ETA: 301s - loss: 0.3008batch number:  492 , cumulative batch number:  58
# 312/587 [==============>...............] - ETA: 301s - loss: 0.3017batch number:  493 , cumulative batch number:  58
# 313/587 [==============>...............] - ETA: 300s - loss: 0.3027batch number:  494 , cumulative batch number:  58
# 314/587 [===============>..............] - ETA: 300s - loss: 0.3037batch number:  495 , cumulative batch number:  58
# 315/587 [===============>..............] - ETA: 299s - loss: 0.3046batch number:  496 , cumulative batch number:  58
# 316/587 [===============>..............] - ETA: 299s - loss: 0.3057batch number:  497 , cumulative batch number:  58
# 317/587 [===============>..............] - ETA: 299s - loss: 0.3067batch number:  498 , cumulative batch number:  58
# 318/587 [===============>..............] - ETA: 298s - loss: 0.3076batch number:  499 , cumulative batch number:  58
# 319/587 [===============>..............] - ETA: 298s - loss: 0.3086batch number:  500 , cumulative batch number:  58
# 320/587 [===============>..............] - ETA: 297s - loss: 0.3097batch number:  501 , cumulative batch number:  58
# 321/587 [===============>..............] - ETA: 297s - loss: 0.3107batch number:  502 , cumulative batch number:  58
# 322/587 [===============>..............] - ETA: 296s - loss: 0.3117batch number:  503 , cumulative batch number:  58
# 323/587 [===============>..............] - ETA: 296s - loss: 0.3127batch number:  504 , cumulative batch number:  58
# 324/587 [===============>..............] - ETA: 296s - loss: 0.3139batch number:  505 , cumulative batch number:  58
# 325/587 [===============>..............] - ETA: 295s - loss: 0.3149batch number:  506 , cumulative batch number:  58
# 326/587 [===============>..............] - ETA: 295s - loss: 0.3159batch number:  507 , cumulative batch number:  58
# 327/587 [===============>..............] - ETA: 294s - loss: 0.3170batch number:  508 , cumulative batch number:  58
# 328/587 [===============>..............] - ETA: 294s - loss: 0.3180batch number:  509 , cumulative batch number:  58
# 329/587 [===============>..............] - ETA: 293s - loss: 0.3191batch number:  510 , cumulative batch number:  58
# 330/587 [===============>..............] - ETA: 293s - loss: 0.3201batch number:  511 , cumulative batch number:  58
# 331/587 [===============>..............] - ETA: 292s - loss: 0.3212batch number:  512 , cumulative batch number:  58
# 332/587 [===============>..............] - ETA: 292s - loss: 0.3222batch number:  513 , cumulative batch number:  58
# 333/587 [===============>..............] - ETA: 292s - loss: 0.3232batch number:  514 , cumulative batch number:  58
# 334/587 [================>.............] - ETA: 291s - loss: 0.3243batch number:  515 , cumulative batch number:  58
# 335/587 [================>.............] - ETA: 291s - loss: 0.3253batch number:  516 , cumulative batch number:  58
# 336/587 [================>.............] - ETA: 290s - loss: 0.3264batch number:  517 , cumulative batch number:  58
# 337/587 [================>.............] - ETA: 290s - loss: 0.3275batch number:  518 , cumulative batch number:  58
# 338/587 [================>.............] - ETA: 289s - loss: 0.3285batch number:  519 , cumulative batch number:  58
# 339/587 [================>.............] - ETA: 289s - loss: 0.3297batch number:  520 , cumulative batch number:  58
# 340/587 [================>.............] - ETA: 288s - loss: 0.3308batch number:  521 , cumulative batch number:  58
# 341/587 [================>.............] - ETA: 288s - loss: 0.3320batch number:  522 , cumulative batch number:  58
# 342/587 [================>.............] - ETA: 287s - loss: 0.3329batch number:  523 , cumulative batch number:  58
# 343/587 [================>.............] - ETA: 287s - loss: 0.3339batch number:  524 , cumulative batch number:  58
# 344/587 [================>.............] - ETA: 286s - loss: 0.3350batch number:  525 , cumulative batch number:  58
# 345/587 [================>.............] - ETA: 286s - loss: 0.3361batch number:  526 , cumulative batch number:  58
# 346/587 [================>.............] - ETA: 286s - loss: 0.3371batch number:  527 , cumulative batch number:  58
# 347/587 [================>.............] - ETA: 285s - loss: 0.3381batch number:  528 , cumulative batch number:  58
# 348/587 [================>.............] - ETA: 285s - loss: 0.3392batch number:  529 , cumulative batch number:  58
# 349/587 [================>.............] - ETA: 284s - loss: 0.3402batch number:  530 , cumulative batch number:  58
# 350/587 [================>.............] - ETA: 284s - loss: 0.3413batch number:  531 , cumulative batch number:  58
# 351/587 [================>.............] - ETA: 283s - loss: 0.3423batch number:  532 , cumulative batch number:  58
# 352/587 [================>.............] - ETA: 283s - loss: 0.3434batch number:  533 , cumulative batch number:  58
# 353/587 [=================>............] - ETA: 282s - loss: 0.3444batch number:  534 , cumulative batch number:  58
# 354/587 [=================>............] - ETA: 282s - loss: 0.3456batch number:  535 , cumulative batch number:  58
# 355/587 [=================>............] - ETA: 281s - loss: 0.3466batch number:  536 , cumulative batch number:  58
# 356/587 [=================>............] - ETA: 281s - loss: 0.3478batch number:  537 , cumulative batch number:  58
# 357/587 [=================>............] - ETA: 280s - loss: 0.3489batch number:  538 , cumulative batch number:  58
# 358/587 [=================>............] - ETA: 280s - loss: 0.3501batch number:  539 , cumulative batch number:  58
# 359/587 [=================>............] - ETA: 279s - loss: 0.3512batch number:  540 , cumulative batch number:  58
# 360/587 [=================>............] - ETA: 279s - loss: 0.3523batch number:  541 , cumulative batch number:  58
# 361/587 [=================>............] - ETA: 278s - loss: 0.3534batch number:  542 , cumulative batch number:  58
# 362/587 [=================>............] - ETA: 278s - loss: 0.3546batch number:  543 , cumulative batch number:  58
# 363/587 [=================>............] - ETA: 277s - loss: 0.3557batch number:  544 , cumulative batch number:  58
# 364/587 [=================>............] - ETA: 277s - loss: 0.3569batch number:  545 , cumulative batch number:  58
# 365/587 [=================>............] - ETA: 276s - loss: 0.3579batch number:  546 , cumulative batch number:  58
# 366/587 [=================>............] - ETA: 276s - loss: 0.3591batch number:  547 , cumulative batch number:  58
# 367/587 [=================>............] - ETA: 275s - loss: 0.3603batch number:  548 , cumulative batch number:  58
# 368/587 [=================>............] - ETA: 275s - loss: 0.3615batch number:  549 , cumulative batch number:  58
# 369/587 [=================>............] - ETA: 274s - loss: 0.3627batch number:  550 , cumulative batch number:  58
# 370/587 [=================>............] - ETA: 274s - loss: 0.3639batch number:  551 , cumulative batch number:  58
# 371/587 [=================>............] - ETA: 273s - loss: 0.3650batch number:  552 , cumulative batch number:  58
# 372/587 [=================>............] - ETA: 273s - loss: 0.3662batch number:  553 , cumulative batch number:  58
# 373/587 [==================>...........] - ETA: 272s - loss: 0.3673batch number:  554 , cumulative batch number:  58
# 374/587 [==================>...........] - ETA: 272s - loss: 0.3685batch number:  555 , cumulative batch number:  58
# 375/587 [==================>...........] - ETA: 271s - loss: 0.3696batch number:  556 , cumulative batch number:  58
# 376/587 [==================>...........] - ETA: 271s - loss: 0.3708batch number:  557 , cumulative batch number:  58
# 377/587 [==================>...........] - ETA: 270s - loss: 0.3720batch number:  558 , cumulative batch number:  58
# 378/587 [==================>...........] - ETA: 270s - loss: 0.3732batch number:  559 , cumulative batch number:  58
# 379/587 [==================>...........] - ETA: 269s - loss: 0.3744batch number:  560 , cumulative batch number:  58
# 380/587 [==================>...........] - ETA: 269s - loss: 0.3756batch number:  561 , cumulative batch number:  58
# 381/587 [==================>...........] - ETA: 269s - loss: 0.3767batch number:  562 , cumulative batch number:  58
# 382/587 [==================>...........] - ETA: 268s - loss: 0.3780batch number:  563 , cumulative batch number:  58
# 383/587 [==================>...........] - ETA: 268s - loss: 0.3792batch number:  564 , cumulative batch number:  58
# 384/587 [==================>...........] - ETA: 267s - loss: 0.3805batch number:  565 , cumulative batch number:  58
# 385/587 [==================>...........] - ETA: 267s - loss: 0.3817batch number:  566 , cumulative batch number:  58
# 386/587 [==================>...........] - ETA: 266s - loss: 0.3830batch number:  567 , cumulative batch number:  58
# 387/587 [==================>...........] - ETA: 266s - loss: 0.3843batch number:  568 , cumulative batch number:  58
# 388/587 [==================>...........] - ETA: 265s - loss: 0.3858batch number:  569 , cumulative batch number:  58
# 389/587 [==================>...........] - ETA: 265s - loss: 0.3870batch number:  570 , cumulative batch number:  58
# 390/587 [==================>...........] - ETA: 264s - loss: 0.3883batch number:  571 , cumulative batch number:  58
# 391/587 [==================>...........] - ETA: 264s - loss: 0.3896batch number:  572 , cumulative batch number:  58
# 392/587 [===================>..........] - ETA: 263s - loss: 0.3910batch number:  573 , cumulative batch number:  58
# 393/587 [===================>..........] - ETA: 263s - loss: 0.3923batch number:  574 , cumulative batch number:  58
# 394/587 [===================>..........] - ETA: 262s - loss: 0.3936batch number:  575 , cumulative batch number:  58
# 395/587 [===================>..........] - ETA: 262s - loss: 0.3950batch number:  576 , cumulative batch number:  58
# 396/587 [===================>..........] - ETA: 261s - loss: 0.3963batch number:  577 , cumulative batch number:  58
# 397/587 [===================>..........] - ETA: 261s - loss: 0.3976batch number:  578 , cumulative batch number:  58
# 398/587 [===================>..........] - ETA: 260s - loss: 0.3989batch number:  579 , cumulative batch number:  58
# 399/587 [===================>..........] - ETA: 260s - loss: 0.4004batch number:  580 , cumulative batch number:  58
# 400/587 [===================>..........] - ETA: 260s - loss: 0.4018batch number:  581 , cumulative batch number:  58
# 401/587 [===================>..........] - ETA: 259s - loss: 0.4033batch number:  582 , cumulative batch number:  58
# 402/587 [===================>..........] - ETA: 259s - loss: 0.4047batch number:  583 , cumulative batch number:  58
# 403/587 [===================>..........] - ETA: 258s - loss: 0.4061batch number:  584 , cumulative batch number:  58
# 404/587 [===================>..........] - ETA: 258s - loss: 0.4075batch number:  585 , cumulative batch number:  58
# 405/587 [===================>..........] - ETA: 257s - loss: 0.4090batch number:  586 , cumulative batch number:  58
# 406/587 [===================>..........] - ETA: 257s - loss: 0.4104batch number:  587 , cumulative batch number:  58
# 407/587 [===================>..........] - ETA: 257s - loss: 0.4119batch number:  588 , cumulative batch number:  58

# %%
# Some simple test of model prediction performance
test_set = shakespeare_gen.__next__()
prediction = model.predict_on_batch(test_set[0])
for i in range(len(test_set[1])):

    sentence = np.argmax(test_set[0][0][i], axis=1)
    sentence_decode = ''
    for t in range(len(sentence)):
        sentence_decode += indices_char[sentence[t]]

    frag = np.argmax(test_set[0][1][i], axis=1)
    frag_decode = ''
    for t in range(len(frag)):
        frag_decode += indices_char[frag[t]]

    predicted_symbols = np.argmax(prediction[i], axis=1)
    predicted_sec = ''
    true_symbols = np.argmax(test_set[1][i,:,:], axis=1)
    true_sec = ''
    for t in range(len(predicted_symbols)):
        predicted_sec += indices_char[predicted_symbols[t]]
        true_sec += indices_char[true_symbols[t]]
    print('Sentence: ', sentence_decode)
    print('Predicted: \"%s\"' % (predicted_sec))
# Out:
# batch number:  170 , cumulative batch number:  57
# Sentence:  #pray , give me that ; i'll carry it to the pile ._
# Predicted: "pray , give me mhat p i'll paley tt ,o mhe male ,_a"
# Sentence:  #as you like this , give me the lie another time ._
# Predicted: "as you like yhis y live ye thi liks,ndnher ,ime ,_i"
# Sentence:  #what is this maid , with whom thou wast at play ?_
# Predicted: "what is this maid , mithiaiim ihiu iiit ,i miii ,ti"
# Sentence:  #so , by your circumstance , i fear you'll prove ._
# Predicted: "so , by your bircumstance , i ciar yourrl ,rici ,ii"
# Sentence:  #look , here is writ 'kind julia :' unkind julia !_
# Predicted: "look , here is hrit iril  ,udie :  hrrisd hodia ,'r"
# Sentence:  #madam , dinner is ready , and your father stays ._
# Predicted: "madam , didner is deady , and ionr diiher iiin  i_o"
# Sentence:  #give ye good even : here's a million of manners ._
# Predicted: "give ye go d even y yere's a goneeon ,' hen'ers ,' "
# Sentence:  #sir valentine and servant , to you two thousand ._
# Predicted: "sir velentine and vevvantza vanyeurarerahausand aea"
# Sentence:  #be not like your mistress : be moved , be moved ._
# Predicted: "be not like your listre   : yi lirid yiyiisives y_t"
# Sentence:  #now , tell me , how do all from whence you came ?_
# Predicted: "now , tell me , tew ,e ,ll teom mhence ,ou ,ole ,do"
# Sentence:  #the more thou damm'st it up , the more it burns ._
# Predicted: "the more thou mom''st tt mpom mhe aore it iatn' i_ "
# Sentence:  #i'll after , to rejoice in the boy's correction ._
# Predicted: "i'll after , to rejoice in the jey s aoreection ,_ "
# Sentence:  #but love will not be spurr'd to what it loathes ._
# Predicted: "but love lill not le looln'd io liit lt lovdher s_ "
# Sentence:  #these likelihoods confirm her flight from hence ._
# Predicted: "these likelieoodscconfidmsheroloonhtscoom hence c_i"
# Sentence:  #dear gentlewoman ,  how fares our gracious lady ?_
# Predicted: "dear gentlewoman ,  hew oawew our goeceous ,owy ,_ "
# Sentence:  #a million of beating may come to a great matter ._
# Predicted: "a million of beiting iol bomelboib biiatimiiier b_i"
# Sentence:  #wherefore , gentle maiden , do you neglect them ?_
# Predicted: "wherefore , geotle maiden , geggeu geilecii,hem ,_o"
# Sentence:  #not a word , a word : we stand upon our manners ._
# Predicted: "not a word , a word , ae atand ,pon , r wan er  ,w "
# Sentence:  #i see the play so lies  that i must bear a part ._
# Predicted: "i see the play sh lies tthat p pust se r t sllt  t "
# Sentence:  #[takes off his false beard .] how now , rustics !_
# Predicted: "[takes oft tim faise iearssh_ hil faw i haftaae i_ "
# Sentence:  #hath not my gait in it the measure of the court ?_
# Predicted: "hath not my gain nn mt ghe naanur  in ihe iaunt i_a"
# Sentence:  #fear thou no wife ; i'll have no wife , paulina ._
# Predicted: "fear thou no wofe ; i'll have io wife ; iaifine w' "
# Sentence:  #then , good my lords , bear witness to his oath ._
# Predicted: "then , good my lord  , gyar mithess oo oim lrrhe,_e"
# Sentence:  #ay , and have been so any time these four hours ._
# Predicted: "ay , and have been ha bny hime bheye boer hanr  a_ "
# Sentence:  #i see them not with my old eyes : what are they ?_
# Predicted: "i see them not tith ty tnd tne  : wiit nne nhei nno"
# Sentence:  #no , i warrant you ; for a fool's will shame it ._
# Predicted: "no , i warrant you ; for a warl s yinl ,here yn y_o"
# Sentence:  #a whoreson dog , that shall palter thus with us !_
# Predicted: "a whoresonddogsw whot doollowore r thos ,hlh ss ,da"
# Sentence:  #come , thou shalt bear a letter to him straight ._
# Predicted: "come , thou shalt be r t toater to aam aerannht ,_ "
# Sentence:  #so now , fair prince of troy , i bid good-night ._
# Predicted: "so now , fair paince ,f taayan annad frod ninht ,_ "
# Sentence:  #this place is dangerous ; the time right deadly ._
# Predicted: "this place is dencerous i ihe pame aacha iaad y ,ta"
# Sentence:  #my lord ,  i will be patient ; outwardly i will ._
# Predicted: "my lord ,    will ,e ,alienc , iur ird y w lill b_a"
# Sentence:  #why then , fly on , i'll hunt thee for thy hide ._
# Predicted: "why then , fly ,l , i'll funt ohee ,or ,hy hune ,_ "
# Sentence:  #here lies thy heart , thy sinews , and thy bone ._
# Predicted: "here lies thy heart , thy hirewe , trd thy here ,_e"
# Sentence:  #the bruit is , hector's slain , and by achilles ._
# Predicted: "the bruit is i bertor's ituin , hcd hr hccieles',_ "
# Sentence:  #fair lady , do you think you have fools in hand ?_
# Predicted: "fair lady , dovyou lhink you ,eve ,old  ,  tedd ,dy"
# Sentence:  #marry , but you shall have ; and here's my hand ._
# Predicted: "marry , but you baall bave b bnd sere's sy hand ,_a"
# Sentence:  #wherefore have these gifts a curtain before 'em ?_
# Predicted: "wherefore have hhere hifts h hhrssin 'efore 'tm a_i"
# Sentence:  #the honourable lady of the house , which is she ?_
# Predicted: "the honourable lady of hhe aaure o lhach is loe o_o"
# Sentence:  #what thriftless sighs shall poor olivia breathe !_
# Predicted: "what throftless sight thall siir sldvea sieathesssh"
# Sentence:  #to hear by the nose , it is dulcet in contagion ._
# Predicted: "to hear by hhe bobe , bs hs dusye  in tonsegeon ,_ "
# Sentence:  #by'r lady , sir , and some dogs will catch well ._
# Predicted: "by'r lady , sir , ald sime ,ig  ,ill ,aleh ,i l ,'o"
# Sentence:  #marry , sir , sometimes he is a kind of puritan ._
# Predicted: "marry , sir , simerime  ,e is s sisdr,f soretyyd,_e"
# Sentence:  #my purpose is , indeed , a horse of that colour ._
# Predicted: "my purpose is , indeed , ispurse ,' ihat ,uudurs,,n"
# Sentence:  #grace and good disposition attend your ladyship !_
# Predicted: "grace and good aiscosenion an end mour gosiship i_o"
# Sentence:  #not black in my mind , though yellow in my legs ._
# Predicted: "not black in my mind i mhough ietlow in my mig  ,]i"
# Sentence:  #why dost thou smile so and kiss thy hand so oft ?_
# Predicted: "why dost thou dmile tomdmd tils thy dold oo eft s_i"
# Sentence:  #not malvolio , nor after my degree , but fellow ._
# Predicted: "not malvoliol, nor mlter io novroe , nut nallow n_a"
# Sentence:  #nothing but this ; your true love for my master ._
# Predicted: "nothing but this y your tuut tove tur ty tuster t_o"
# Sentence:  #thou hast , sebastian , done good feature shame ._
# Predicted: "thou hast , sebastian , hese ,aad ,aasura ,hale ,go"
# Sentence:  #alas , sir , how fell you beside your five wits ?_
# Predicted: "alas , sir , sow follo,ou ,ihide ,ou  ,ove ,ith ,_e"
# Sentence:  #now , as thou lovest me , let me see his letter ._
# Predicted: "now , as thou aovest ,e , lottmo sor ,os motter ,_o"
# Sentence:  #a savage jealousy  that sometimes savours nobly ._
# Predicted: "a savage jaalousy  ahat jave iaes  aveury  o ly t_a"
# Sentence:  #how have you done , since last we saw in france ?_
# Predicted: "how have you done i hince yodt yi din yncdoance ,_ "
# Sentence:  #all the whole time  i was my chamber's prisoner ._
# Predicted: "all the whole time  i whl ty thiiber s tiieon    ' "
# Sentence:  #there's his period ; to sheathe his knife in us ._
# Predicted: "there's his period ; ho peedrhe iis peige ,s tses_e"
# Sentence:  #what war-like voice , and to what end , is this ?_
# Predicted: "what war-like-voice w lnd lo-lhit enc-, is this v_o"
# Sentence:  #you're excus'd : but will you be more justified ?_
# Predicted: "you're exc's'd : but will you be suse ,usticied ,_o"
# Sentence:  #have i not made you  the prime man of the state ?_
# Predicted: "have i not made you nphe nrineniad if the maaie y_o"
# Sentence:  #my lords , can ye endure to hear this arrogance ?_
# Predicted: "my lords , car yo cndure ,o cear uhis eneegence ,_e"
# Sentence:  #so fare you well , my little good lord cardinal ._
# Predicted: "so fare you well , wy little yedd werd ,aleinal ,_e"
# Sentence:  #that's somewhat sudden : but he's a learned man ._
# Predicted: "that's somewhat sudden wwbut sews a suasn'd ,an ,' "
# Sentence:  #you do desire to know  wherefore i sent for you ._
# Predicted: "you do desire to dnow ddhere ore i dent aor your _e"
# Sentence:  #bless me , what a fry of fornication is at door !_
# Predicted: "bless me , what a mra ,f mar ycaleon ,s a  mrnr ,_r"
# Sentence:  #do not thou , when thou art king , hang a thief ._
# Predicted: "do not thou t when thou wrt wing , wavg a whoef w_ "

# %%
def sentence_encode(sentence):
    y = np.zeros((1, len(sentence), len(chars)), dtype=np.int32)
    for t, char in enumerate(sentence):
        y[0, t, char_indices[char]] = 1
    return y
        
test_sentence = "#fight valiantly to-day : and yet i do thee wrong to mind thee of it , for thou art fram'd of the firm truth of valour ._"
test_sentence = "#i predict that robots shall be useful ._"

#test_sentence = "#have i forgotten myself so far that i have not even told you his name ?_"
#test_sentence = "#fight valiantly to-day : and yet i do thee wrong to mind thee of it ._"


#test_sentence_encoded = np.reshape(test_set[0][0][-1,:,:], (1,121,len(chars)))
test_sentence_encoded = sentence_encode(test_sentence)
#test_sentence_encoded = np.concatenate([test_sentence_encoded, np.zeros((1, 0, len(chars)))], axis=1)
test_shot = [test_sentence_encoded, test_sentence_encoded]
prediction_example = model.predict_on_batch(test_shot)[-1,:,:]

predicted_sec = ''
predicted_symbols = np.argmax(prediction_example, axis=1)
for t in range(len(predicted_symbols)):
    predicted_sec += indices_char[predicted_symbols[t]]
    
print('Predicted sec:')
predicted_sec
# Out:
# Predicted sec:
# 'i prediceithat pobidi thall re pradol t_o'

# %% [raw]
# test_sentence_char_codes = np.argmax(test_frag_encoded, axis=2).ravel()
# test_sentence_decode = ''
# for t in range(len(test_sentence_char_codes)):
#     test_sentence_decode += indices_char[test_sentence_char_codes[t]]
# test_sentence_decode

# %%
test_pred = model.predict([np.reshape(test_set[0][0][0,:,:], (1,-1, len(chars))), 
                        np.reshape(test_set[0][1][0,:,:], (1,-1, len(chars)))])
indices_char[np.argmax(test_pred)]
# Out:
# 'e'

# %%
test_pred = model.predict([test_sentence_encoded, 
                        np.reshape(test_set[0][1][0,:,:], (1,-1, len(chars)))])
indices_char[np.argmax(test_pred)]
# Out:
# '-'

# %%
test_set[0][1][:,:,:].shape
# Out:
# (80, 32, 56)

# %%
test_frag_encoded.shape
# Out:
# (1, 78, 56)

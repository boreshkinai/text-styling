# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, GRU, Input, Flatten, Masking, merge, Reshape, Lambda, TimeDistributed, Dropout
from keras.layers.merge import Concatenate, Add
from keras import backend as K
from keras.optimizers import RMSprop, SGD, Adam
from keras.utils.data_utils import get_file
from keras.models import Model
import numpy as np
import random
import sys
import re

DROPOUT = 0.1
SENTENCE_BATCH_SIZE = 128
LSTM_WIDTH = 512
SENTENCE_START = '#'
SENTENCE_END = '_'

caps = "([A-Z])"
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co)"
starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
websites = "[.](com|net|org|io|gov)"

def split_into_sentences(text):
    text = " " + text + "  "
    text = text.replace("\n"," ")
    text = re.sub(prefixes,"\\1<prd>",text)
    text = re.sub(websites,"<prd>\\1",text)
    if "Ph.D" in text: text = text.replace("Ph.D.","Ph<prd>D<prd>")
    text = re.sub("\s" + caps + "[.] "," \\1<prd> ",text)
    text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
    text = re.sub(caps + "[.]" + caps + "[.]" + caps + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
    text = re.sub(caps + "[.]" + caps + "[.]","\\1<prd>\\2<prd>",text)
    text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
    text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
    text = re.sub(" " + caps + "[.]"," \\1<prd>",text)
    if "”" in text: text = text.replace(".”","”.")
    if "\"" in text: text = text.replace(".\"","\".")
    if "!" in text: text = text.replace("!\"","\"!")
    if "?" in text: text = text.replace("?\"","\"?")
    #if "\'" in text: text = text.replace("\'", " ")
    text = text.replace(". ","."+SENTENCE_END+"<stop> ")
    text = text.replace("? ","?"+SENTENCE_END+"<stop> ")
    text = text.replace("! ","!"+SENTENCE_END+"<stop> ")
    text = text.replace("<prd> ",".")
    sentences = text.split("<stop>")
    sentences = sentences[:-1]
    sentences = [s.strip() for s in sentences]
    out = []
    for s in sentences:
        if (len(s) > 30) and (len(s) < 500):
            out.append(SENTENCE_START+s)
    return out


path_shakespeare = get_file('shakespeare.txt', origin='http://norvig.com/ngrams/shakespeare.txt')
text_shakespeare = open(path_shakespeare).read()
text_shakespeare = text_shakespeare.lower().replace('\n', ' ').replace('=', ' ').replace(r"\\'", " ")
print('corpus length:', len(text_shakespeare))

# nltk.download()
#tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
#tokenized = tokenizer.tokenize(text)

sentences_shakespeare = np.array(split_into_sentences(text_shakespeare))
sentences_shakespeare = sorted(sentences_shakespeare, key=len)
chars = sorted(list(set("".join(sentences_shakespeare))))

print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

def text_generator(sentences):

    cum_count=0
    while 1:
        count=0
        cum_count += 1
        for i in range(0, len(sentences), SENTENCE_BATCH_SIZE): # len(sentences)
            print('batch number: ', count, ', cumulative batch number: ', cum_count)
            count += 1

            sentence_batch = sentences[i:i + SENTENCE_BATCH_SIZE]
            maxlen_batch = len(max(sentence_batch, key=len))

            X = np.zeros((SENTENCE_BATCH_SIZE, maxlen_batch, len(chars)), dtype=np.int32)
            y = np.zeros((SENTENCE_BATCH_SIZE, maxlen_batch, len(chars)), dtype=np.int32)
            w = np.zeros((SENTENCE_BATCH_SIZE, maxlen_batch), dtype=np.int32)

            for i, sentence in enumerate(sentence_batch):

                for t, char in enumerate(sentence):
                    X[i, t, char_indices[char]] = 1

                for t in range(len(sentence)-1):
                    taget_pos = t+1
                    y[i, t, char_indices[sentence[taget_pos]]] = 1
                    w[i, t] = 1

            yield ([X, X], y, w)



print('Build model...')


def concat_context(inputs):
    seq = inputs[0]
    c = inputs[1]
    c_tiled = K.tile(K.reshape(c, [-1, 1, 512]), (1,K.shape(seq)[1],1) )
    out = K.concatenate([seq, c_tiled], axis=2)

    boolean_mask = K.any(K.not_equal(seq, 0), axis=-1, keepdims=True)

    # K.print_tensor( out * K.cast(boolean_mask, K.floatx()) )

    return out * K.cast(boolean_mask, K.floatx())


def get_encoder(lstm_width, dropout):
    context_input = Input(shape=(None, len(chars)))
    x = Masking(mask_value=0)(context_input)
    x = GRU(lstm_width, return_sequences=True, go_backwards=True, dropout=dropout)(x)
    #xf = GRU(LSTM_WIDTH, return_sequences=True, go_backwards=False, dropout=0.0)(x)
    #x = Concatenate(axis=2)([xf, xb])
    x = GRU(lstm_width, return_sequences=True, dropout=dropout)(x)
    encoder_output = GRU(lstm_width, return_sequences=False, dropout=dropout)(x)
    
    return Model(inputs=[context_input], outputs=[encoder_output])    
    
    
def get_autoencoder(encoder, lstm_width, dropout):
    context_input = Input(shape=(None, len(chars)))
    encoder_output = encoder(context_input)
    #encoder_output = Reshape((1,lstm_width))(encoder_output)

    teacher_input = Input(shape=(None, len(chars)))
    decoder_input = Masking(mask_value=0)(teacher_input)

    context_layer1 = Lambda(concat_context)
    decoder_input_c = context_layer1([decoder_input, encoder_output])

    y1 = GRU(lstm_width, return_sequences=True, dropout=dropout)(decoder_input_c)
    y2 = GRU(lstm_width, return_sequences=True, dropout=dropout)(y1)
    y3 = GRU(lstm_width, return_sequences=True, dropout=dropout)(y2)

    context_layer2 = Lambda(concat_context)
    decoder_appended = context_layer2([y3, encoder_output])

    decoder_appended = TimeDistributed(Dense(lstm_width, activation='relu'))(decoder_appended)
    decoder_appended = TimeDistributed(Dropout(0.5))(decoder_appended)
    decoder_output = TimeDistributed(Dense(len(chars), activation='softmax'))(decoder_appended)

    return Model(inputs=[context_input, teacher_input], outputs=[decoder_output])

    
encoder = get_encoder(lstm_width=LSTM_WIDTH, dropout=DROPOUT)
shakespeare_autoencoder = get_autoencoder(encoder, lstm_width=LSTM_WIDTH, dropout=DROPOUT)

optimizer = Adam(clipnorm=1.0)
shakespeare_autoencoder.compile(loss='categorical_crossentropy', optimizer=optimizer, sample_weight_mode="temporal")


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


shakespeare_gen = text_generator(sentences_shakespeare)

for iteration in range(1, 100):
    print()
    print('-' * 50)
    print('Iteration', iteration)

    shakespeare_autoencoder.save('model_shakespeare.hd5')
    shakespeare_history = shakespeare_autoencoder.fit_generator(shakespeare_gen, 
                            steps_per_epoch=len(sentences_shakespeare)/SENTENCE_BATCH_SIZE-10, 
                            epochs=1, verbose=1, workers=1)
# Out:
# corpus length: 4538523
# total chars: 45
# Build model...
#
# --------------------------------------------------
# Iteration 1
# batch number: Epoch 1/1
#  0 , cumulative batch number:  1
# batch number:  1 , cumulative batch number:  1
# batch number:  2 , cumulative batch number:  1
# batch number:  3 , cumulative batch number:  1
# batch number:  4 , cumulative batch number:  1
# batch number:  5 , cumulative batch number:  1
# batch number:  6 , cumulative batch number:  1
# batch number:  7 , cumulative batch number:  1
# batch number:  8 , cumulative batch number:  1
# batch number:  9 , cumulative batch number:  1
# batch number:  10 , cumulative batch number:  1
#   1/288 [..............................] - ETA: 694s - loss: 3.8095batch number:  11 , cumulative batch number:  1
#   2/288 [..............................] - ETA: 420s - loss: 3.7869batch number:  12 , cumulative batch number:  1
#   3/288 [..............................] - ETA: 336s - loss: 3.7140batch number:  13 , cumulative batch number:  1
#   4/288 [..............................] - ETA: 297s - loss: 3.9003batch number:  14 , cumulative batch number:  1
#   5/288 [..............................] - ETA: 269s - loss: 3.7922batch number:  15 , cumulative batch number:  1
#   6/288 [..............................] - ETA: 250s - loss: 3.7183batch number:  16 , cumulative batch number:  1
#   7/288 [..............................] - ETA: 237s - loss: 3.6603batch number:  17 , cumulative batch number:  1
#   8/288 [..............................] - ETA: 228s - loss: 3.6074batch number:  18 , cumulative batch number:  1
#   9/288 [..............................] - ETA: 221s - loss: 3.5595batch number:  19 , cumulative batch number:  1
#  10/288 [>.............................] - ETA: 217s - loss: 3.5159batch number:  20 , cumulative batch number:  1
#  11/288 [>.............................] - ETA: 212s - loss: 3.4845batch number:  21 , cumulative batch number:  1
#  12/288 [>.............................] - ETA: 208s - loss: 3.4568batch number:  22 , cumulative batch number:  1
#  13/288 [>.............................] - ETA: 205s - loss: 3.4283batch number:  23 , cumulative batch number:  1
#  14/288 [>.............................] - ETA: 203s - loss: 3.4087batch number:  24 , cumulative batch number:  1
#  15/288 [>.............................] - ETA: 200s - loss: 3.3871batch number:  25 , cumulative batch number:  1
#  16/288 [>.............................] - ETA: 198s - loss: 3.3699batch number:  26 , cumulative batch number:  1
#  17/288 [>.............................] - ETA: 196s - loss: 3.3547batch number:  27 , cumulative batch number:  1
#  18/288 [>.............................] - ETA: 194s - loss: 3.3385batch number:  28 , cumulative batch number:  1
#  19/288 [>.............................] - ETA: 192s - loss: 3.3227batch number:  29 , cumulative batch number:  1
#  20/288 [=>............................] - ETA: 190s - loss: 3.3101batch number:  30 , cumulative batch number:  1
#  21/288 [=>............................] - ETA: 189s - loss: 3.2974batch number:  31 , cumulative batch number:  1
#  22/288 [=>............................] - ETA: 188s - loss: 3.2866batch number:  32 , cumulative batch number:  1
#  23/288 [=>............................] - ETA: 188s - loss: 3.2777batch number:  33 , cumulative batch number:  1
#  24/288 [=>............................] - ETA: 186s - loss: 3.2680batch number:  34 , cumulative batch number:  1
#  25/288 [=>............................] - ETA: 186s - loss: 3.2591batch number:  35 , cumulative batch number:  1
#  26/288 [=>............................] - ETA: 186s - loss: 3.2492batch number:  36 , cumulative batch number:  1
#  27/288 [=>............................] - ETA: 185s - loss: 3.2404batch number:  37 , cumulative batch number:  1
#  28/288 [=>............................] - ETA: 184s - loss: 3.2322batch number:  38 , cumulative batch number:  1
#  29/288 [==>...........................] - ETA: 184s - loss: 3.2242batch number:  39 , cumulative batch number:  1
#  30/288 [==>...........................] - ETA: 184s - loss: 3.2163batch number:  40 , cumulative batch number:  1
#  31/288 [==>...........................] - ETA: 184s - loss: 3.2097batch number:  41 , cumulative batch number:  1
#  32/288 [==>...........................] - ETA: 183s - loss: 3.2027batch number:  42 , cumulative batch number:  1
#  33/288 [==>...........................] - ETA: 183s - loss: 3.1956batch number:  43 , cumulative batch number:  1
#  34/288 [==>...........................] - ETA: 182s - loss: 3.1888batch number:  44 , cumulative batch number:  1
#  35/288 [==>...........................] - ETA: 182s - loss: 3.1827batch number:  45 , cumulative batch number:  1
#  36/288 [==>...........................] - ETA: 181s - loss: 3.1755batch number:  46 , cumulative batch number:  1
#  37/288 [==>...........................] - ETA: 181s - loss: 3.1693batch number:  47 , cumulative batch number:  1
#  38/288 [==>...........................] - ETA: 181s - loss: 3.1621batch number:  48 , cumulative batch number:  1
#  39/288 [===>..........................] - ETA: 180s - loss: 3.1554batch number:  49 , cumulative batch number:  1
#  40/288 [===>..........................] - ETA: 180s - loss: 3.1489batch number:  50 , cumulative batch number:  1
#  41/288 [===>..........................] - ETA: 179s - loss: 3.1417batch number:  51 , cumulative batch number:  1
#  42/288 [===>..........................] - ETA: 178s - loss: 3.1347batch number:  52 , cumulative batch number:  1
#  43/288 [===>..........................] - ETA: 178s - loss: 3.1269batch number:  53 , cumulative batch number:  1
#  44/288 [===>..........................] - ETA: 178s - loss: 3.1201batch number:  54 , cumulative batch number:  1
#  45/288 [===>..........................] - ETA: 177s - loss: 3.1127batch number:  55 , cumulative batch number:  1
#  46/288 [===>..........................] - ETA: 176s - loss: 3.1055batch number:  56 , cumulative batch number:  1
#  47/288 [===>..........................] - ETA: 176s - loss: 3.0977batch number:  57 , cumulative batch number:  1
#  48/288 [===>..........................] - ETA: 175s - loss: 3.0894batch number:  58 , cumulative batch number:  1
#  49/288 [====>.........................] - ETA: 175s - loss: 3.0811batch number:  59 , cumulative batch number:  1
#  50/288 [====>.........................] - ETA: 175s - loss: 3.0734batch number:  60 , cumulative batch number:  1
#  51/288 [====>.........................] - ETA: 174s - loss: 3.0669batch number:  61 , cumulative batch number:  1
#  52/288 [====>.........................] - ETA: 174s - loss: 3.0587batch number:  62 , cumulative batch number:  1
#  53/288 [====>.........................] - ETA: 173s - loss: 3.0505batch number:  63 , cumulative batch number:  1
#  54/288 [====>.........................] - ETA: 173s - loss: 3.0422batch number:  64 , cumulative batch number:  1
#  55/288 [====>.........................] - ETA: 173s - loss: 3.0339batch number:  65 , cumulative batch number:  1
#  56/288 [====>.........................] - ETA: 173s - loss: 3.0252batch number:  66 , cumulative batch number:  1
#  57/288 [====>.........................] - ETA: 172s - loss: 3.0161batch number:  67 , cumulative batch number:  1
#  58/288 [=====>........................] - ETA: 172s - loss: 3.0069batch number:  68 , cumulative batch number:  1
#  59/288 [=====>........................] - ETA: 171s - loss: 2.9980batch number:  69 , cumulative batch number:  1
#  60/288 [=====>........................] - ETA: 171s - loss: 2.9895batch number:  70 , cumulative batch number:  1
#  61/288 [=====>........................] - ETA: 171s - loss: 2.9815batch number:  71 , cumulative batch number:  1
#  62/288 [=====>........................] - ETA: 170s - loss: 2.9734batch number:  72 , cumulative batch number:  1
#  63/288 [=====>........................] - ETA: 170s - loss: 2.9654batch number:  73 , cumulative batch number:  1
#  64/288 [=====>........................] - ETA: 169s - loss: 2.9566batch number:  74 , cumulative batch number:  1
#  65/288 [=====>........................] - ETA: 169s - loss: 2.9473batch number:  75 , cumulative batch number:  1
#  66/288 [=====>........................] - ETA: 169s - loss: 2.9391batch number:  76 , cumulative batch number:  1
#  67/288 [=====>........................] - ETA: 168s - loss: 2.9309batch number:  77 , cumulative batch number:  1
#  68/288 [======>.......................] - ETA: 168s - loss: 2.9230batch number:  78 , cumulative batch number:  1
#  69/288 [======>.......................] - ETA: 167s - loss: 2.9155batch number:  79 , cumulative batch number:  1
#  70/288 [======>.......................] - ETA: 167s - loss: 2.9073batch number:  80 , cumulative batch number:  1
#  71/288 [======>.......................] - ETA: 166s - loss: 2.8991batch number:  81 , cumulative batch number:  1
#  72/288 [======>.......................] - ETA: 166s - loss: 2.8917batch number:  82 , cumulative batch number:  1
#  73/288 [======>.......................] - ETA: 165s - loss: 2.8839batch number:  83 , cumulative batch number:  1
#  74/288 [======>.......................] - ETA: 165s - loss: 2.8762batch number:  84 , cumulative batch number:  1
#  75/288 [======>.......................] - ETA: 164s - loss: 2.8687batch number:  85 , cumulative batch number:  1
#  76/288 [======>.......................] - ETA: 164s - loss: 2.8612batch number:  86 , cumulative batch number:  1
#  77/288 [======>.......................] - ETA: 164s - loss: 2.8541batch number:  87 , cumulative batch number:  1
#  78/288 [=======>......................] - ETA: 163s - loss: 2.8463batch number:  88 , cumulative batch number:  1
#  79/288 [=======>......................] - ETA: 163s - loss: 2.8387batch number:  89 , cumulative batch number:  1
#  80/288 [=======>......................] - ETA: 163s - loss: 2.8313batch number:  90 , cumulative batch number:  1
#  81/288 [=======>......................] - ETA: 162s - loss: 2.8238batch number:  91 , cumulative batch number:  1
#  82/288 [=======>......................] - ETA: 162s - loss: 2.8172batch number:  92 , cumulative batch number:  1
#  83/288 [=======>......................] - ETA: 161s - loss: 2.8102batch number:  93 , cumulative batch number:  1
#  84/288 [=======>......................] - ETA: 161s - loss: 2.8034batch number:  94 , cumulative batch number:  1
#  85/288 [=======>......................] - ETA: 160s - loss: 2.7966batch number:  95 , cumulative batch number:  1
#  86/288 [=======>......................] - ETA: 160s - loss: 2.7900batch number:  96 , cumulative batch number:  1
#  87/288 [========>.....................] - ETA: 159s - loss: 2.7834batch number:  97 , cumulative batch number:  1
#  88/288 [========>.....................] - ETA: 159s - loss: 2.7769batch number:  98 , cumulative batch number:  1
#  89/288 [========>.....................] - ETA: 158s - loss: 2.7700batch number:  99 , cumulative batch number:  1
#  90/288 [========>.....................] - ETA: 158s - loss: 2.7639batch number:  100 , cumulative batch number:  1
#  91/288 [========>.....................] - ETA: 158s - loss: 2.7578batch number:  101 , cumulative batch number:  1
#  92/288 [========>.....................] - ETA: 157s - loss: 2.7517batch number:  102 , cumulative batch number:  1
#  93/288 [========>.....................] - ETA: 157s - loss: 2.7453batch number:  103 , cumulative batch number:  1
#  94/288 [========>.....................] - ETA: 156s - loss: 2.7395batch number:  104 , cumulative batch number:  1
#  95/288 [========>.....................] - ETA: 156s - loss: 2.7337batch number:  105 , cumulative batch number:  1
#  96/288 [========>.....................] - ETA: 155s - loss: 2.7277batch number:  106 , cumulative batch number:  1
#  97/288 [=========>....................] - ETA: 155s - loss: 2.7220batch number:  107 , cumulative batch number:  1
#  98/288 [=========>....................] - ETA: 155s - loss: 2.7158batch number:  108 , cumulative batch number:  1
#  99/288 [=========>....................] - ETA: 154s - loss: 2.7098batch number:  109 , cumulative batch number:  1
# 100/288 [=========>....................] - ETA: 154s - loss: 2.7044batch number:  110 , cumulative batch number:  1
# 101/288 [=========>....................] - ETA: 154s - loss: 2.6990batch number:  111 , cumulative batch number:  1
# 102/288 [=========>....................] - ETA: 153s - loss: 2.6935batch number:  112 , cumulative batch number:  1
# 103/288 [=========>....................] - ETA: 153s - loss: 2.6880batch number:  113 , cumulative batch number:  1
# 104/288 [=========>....................] - ETA: 153s - loss: 2.6828batch number:  114 , cumulative batch number:  1
# 105/288 [=========>....................] - ETA: 152s - loss: 2.6776batch number:  115 , cumulative batch number:  1
# 106/288 [==========>...................] - ETA: 152s - loss: 2.6725batch number:  116 , cumulative batch number:  1
# 107/288 [==========>...................] - ETA: 151s - loss: 2.6675batch number:  117 , cumulative batch number:  1
# 108/288 [==========>...................] - ETA: 151s - loss: 2.6626batch number:  118 , cumulative batch number:  1
# 109/288 [==========>...................] - ETA: 150s - loss: 2.6577batch number:  119 , cumulative batch number:  1
# 110/288 [==========>...................] - ETA: 150s - loss: 2.6528batch number:  120 , cumulative batch number:  1
# 111/288 [==========>...................] - ETA: 150s - loss: 2.6485batch number:  121 , cumulative batch number:  1
# 112/288 [==========>...................] - ETA: 149s - loss: 2.6441batch number:  122 , cumulative batch number:  1
# 113/288 [==========>...................] - ETA: 149s - loss: 2.6403batch number:  123 , cumulative batch number:  1
# 114/288 [==========>...................] - ETA: 149s - loss: 2.6359batch number:  124 , cumulative batch number:  1
# 115/288 [==========>...................] - ETA: 148s - loss: 2.6316batch number:  125 , cumulative batch number:  1
# 116/288 [===========>..................] - ETA: 148s - loss: 2.6273batch number:  126 , cumulative batch number:  1
# 117/288 [===========>..................] - ETA: 148s - loss: 2.6228batch number:  127 , cumulative batch number:  1
# 118/288 [===========>..................] - ETA: 147s - loss: 2.6189batch number:  128 , cumulative batch number:  1
# 119/288 [===========>..................] - ETA: 147s - loss: 2.6146batch number:  129 , cumulative batch number:  1
# 120/288 [===========>..................] - ETA: 147s - loss: 2.6104batch number:  130 , cumulative batch number:  1
# 121/288 [===========>..................] - ETA: 146s - loss: 2.6064batch number:  131 , cumulative batch number:  1
# 122/288 [===========>..................] - ETA: 146s - loss: 2.6023batch number:  132 , cumulative batch number:  1
# 123/288 [===========>..................] - ETA: 145s - loss: 2.5983batch number:  133 , cumulative batch number:  1
# 124/288 [===========>..................] - ETA: 145s - loss: 2.5942batch number:  134 , cumulative batch number:  1
# 125/288 [===========>..................] - ETA: 145s - loss: 2.5904batch number:  135 , cumulative batch number:  1
# 126/288 [============>.................] - ETA: 144s - loss: 2.5862batch number:  136 , cumulative batch number:  1
# 127/288 [============>.................] - ETA: 144s - loss: 2.5824batch number:  137 , cumulative batch number:  1
# 128/288 [============>.................] - ETA: 143s - loss: 2.5786batch number:  138 , cumulative batch number:  1
# 129/288 [============>.................] - ETA: 143s - loss: 2.5748batch number:  139 , cumulative batch number:  1
# 130/288 [============>.................] - ETA: 143s - loss: 2.5708batch number:  140 , cumulative batch number:  1
# 131/288 [============>.................] - ETA: 142s - loss: 2.5669batch number:  141 , cumulative batch number:  1
# 132/288 [============>.................] - ETA: 142s - loss: 2.5632batch number:  142 , cumulative batch number:  1
# 133/288 [============>.................] - ETA: 141s - loss: 2.5593batch number:  143 , cumulative batch number:  1
# 134/288 [============>.................] - ETA: 141s - loss: 2.5557batch number:  144 , cumulative batch number:  1
# 135/288 [=============>................] - ETA: 141s - loss: 2.5520batch number:  145 , cumulative batch number:  1
# 136/288 [=============>................] - ETA: 140s - loss: 2.5483batch number:  146 , cumulative batch number:  1
# 137/288 [=============>................] - ETA: 140s - loss: 2.5445batch number:  147 , cumulative batch number:  1
# 138/288 [=============>................] - ETA: 139s - loss: 2.5408batch number:  148 , cumulative batch number:  1
# 139/288 [=============>................] - ETA: 139s - loss: 2.5371batch number:  149 , cumulative batch number:  1
# 140/288 [=============>................] - ETA: 138s - loss: 2.5336batch number:  150 , cumulative batch number:  1
# 141/288 [=============>................] - ETA: 138s - loss: 2.5300batch number:  151 , cumulative batch number:  1
# 142/288 [=============>................] - ETA: 137s - loss: 2.5264batch number:  152 , cumulative batch number:  1
# 143/288 [=============>................] - ETA: 137s - loss: 2.5229batch number:  153 , cumulative batch number:  1
# 144/288 [=============>................] - ETA: 137s - loss: 2.5196batch number:  154 , cumulative batch number:  1
# 145/288 [==============>...............] - ETA: 136s - loss: 2.5164batch number:  155 , cumulative batch number:  1
# 146/288 [==============>...............] - ETA: 136s - loss: 2.5132batch number:  156 , cumulative batch number:  1
# 147/288 [==============>...............] - ETA: 135s - loss: 2.5099batch number:  157 , cumulative batch number:  1
# 148/288 [==============>...............] - ETA: 135s - loss: 2.5065batch number:  158 , cumulative batch number:  1
# 149/288 [==============>...............] - ETA: 134s - loss: 2.5032batch number:  159 , cumulative batch number:  1
# 150/288 [==============>...............] - ETA: 134s - loss: 2.5001batch number:  160 , cumulative batch number:  1
# 151/288 [==============>...............] - ETA: 133s - loss: 2.4966batch number:  161 , cumulative batch number:  1
# 152/288 [==============>...............] - ETA: 133s - loss: 2.4933batch number:  162 , cumulative batch number:  1
# 153/288 [==============>...............] - ETA: 132s - loss: 2.4899batch number:  163 , cumulative batch number:  1
# 154/288 [==============>...............] - ETA: 132s - loss: 2.4868batch number:  164 , cumulative batch number:  1
# 155/288 [===============>..............] - ETA: 131s - loss: 2.4836batch number:  165 , cumulative batch number:  1
# 156/288 [===============>..............] - ETA: 131s - loss: 2.4807batch number:  166 , cumulative batch number:  1
# 157/288 [===============>..............] - ETA: 130s - loss: 2.4777batch number:  167 , cumulative batch number:  1
# 158/288 [===============>..............] - ETA: 130s - loss: 2.4747batch number:  168 , cumulative batch number:  1
# 159/288 [===============>..............] - ETA: 129s - loss: 2.4717batch number:  169 , cumulative batch number:  1
# 160/288 [===============>..............] - ETA: 129s - loss: 2.4686batch number:  170 , cumulative batch number:  1
# 161/288 [===============>..............] - ETA: 128s - loss: 2.4657batch number:  171 , cumulative batch number:  1
# 162/288 [===============>..............] - ETA: 128s - loss: 2.4626batch number:  172 , cumulative batch number:  1
# 163/288 [===============>..............] - ETA: 127s - loss: 2.4597batch number:  173 , cumulative batch number:  1
# 164/288 [================>.............] - ETA: 127s - loss: 2.4566batch number:  174 , cumulative batch number:  1
# 165/288 [================>.............] - ETA: 126s - loss: 2.4536batch number:  175 , cumulative batch number:  1
# 166/288 [================>.............] - ETA: 125s - loss: 2.4507batch number:  176 , cumulative batch number:  1
# 167/288 [================>.............] - ETA: 125s - loss: 2.4477batch number:  177 , cumulative batch number:  1
# 168/288 [================>.............] - ETA: 124s - loss: 2.4448batch number:  178 , cumulative batch number:  1
# 169/288 [================>.............] - ETA: 124s - loss: 2.4417batch number:  179 , cumulative batch number:  1
# 170/288 [================>.............] - ETA: 123s - loss: 2.4387batch number:  180 , cumulative batch number:  1
# 171/288 [================>.............] - ETA: 122s - loss: 2.4358batch number:  181 , cumulative batch number:  1
# 172/288 [================>.............] - ETA: 122s - loss: 2.4329batch number:  182 , cumulative batch number:  1
# 173/288 [================>.............] - ETA: 121s - loss: 2.4300batch number:  183 , cumulative batch number:  1
# 174/288 [=================>............] - ETA: 121s - loss: 2.4273batch number:  184 , cumulative batch number:  1
# 175/288 [=================>............] - ETA: 120s - loss: 2.4244batch number:  185 , cumulative batch number:  1
# 176/288 [=================>............] - ETA: 119s - loss: 2.4217batch number:  186 , cumulative batch number:  1
# 177/288 [=================>............] - ETA: 119s - loss: 2.4188batch number:  187 , cumulative batch number:  1
# 178/288 [=================>............] - ETA: 118s - loss: 2.4158batch number:  188 , cumulative batch number:  1
# 179/288 [=================>............] - ETA: 117s - loss: 2.4130batch number:  189 , cumulative batch number:  1
# 180/288 [=================>............] - ETA: 117s - loss: 2.4100batch number:  190 , cumulative batch number:  1
# 181/288 [=================>............] - ETA: 116s - loss: 2.4072batch number:  191 , cumulative batch number:  1
# 182/288 [=================>............] - ETA: 115s - loss: 2.4045batch number:  192 , cumulative batch number:  1
# 183/288 [=================>............] - ETA: 115s - loss: 2.4018batch number:  193 , cumulative batch number:  1
# 184/288 [==================>...........] - ETA: 114s - loss: 2.3989

# %%
# Some simple test of model prediction performance
test_set = shakespeare_gen.__next__()
prediction = shakespeare_autoencoder.predict_on_batch(test_set[0])
for i in range(len(test_set[1])):

    sentence = np.argmax(test_set[0][0][i], axis=1)
    sentence_decode = ''
    for t in range(len(sentence)):
        sentence_decode += indices_char[sentence[t]]

    frag = np.argmax(test_set[0][1][i], axis=1)
    frag_decode = ''
    for t in range(len(frag)):
        frag_decode += indices_char[frag[t]]

    predicted_symbols = np.argmax(prediction[i], axis=1)
    predicted_sec = ''
    true_symbols = np.argmax(test_set[1][i,:,:], axis=1)
    true_sec = ''
    for t in range(len(predicted_symbols)):
        predicted_sec += indices_char[predicted_symbols[t]]
        true_sec += indices_char[true_symbols[t]]
    print('Sentence: ', sentence_decode)
    print('Predicted: \"%s\"' % (predicted_sec))
# Out:
# batch number:  2 , cumulative batch number:  100
# Sentence:  #ay , greek , that is my name ._
# Predicted: "ay , greek , that is my name ._ "
# Sentence:  #thou mayst tell that knowest ._
# Predicted: "thou mayst tell that knowest ._ "
# Sentence:  #what is he more than another ?_
# Predicted: "what is he more than another ?_ "
# Sentence:  #you depend upon him , i mean ?_
# Predicted: "you depend upon him , i mean ?_ "
# Sentence:  #nell , he is full of harmony ._
# Predicted: "nell , he is full of harmony ._ "
# Sentence:  #but , marry , thus , my lord ._
# Predicted: "but , marry , thur , my lord ._ "
# Sentence:  #come , your disposer is sick ._
# Predicted: "come , your disposer is sick a_ "
# Sentence:  #come , give me an instrument ._
# Predicted: "come , give me an instrument ._ "
# Sentence:  #hot thoughts , and hot deeds ?_
# Predicted: "hot thoughts , and hot deeds ?_ "
# Sentence:  #shall ajax fight with hector ?_
# Predicted: "shall ajax fight with hector ?_ "
# Sentence:  #on , lord ; we'll follow you ._
# Predicted: "on , lord ; we'll follow you ._ "
# Sentence:  #there was never a truer rime ._
# Predicted: "there was never a truer rime t_ "
# Sentence:  #you have not patience ; come ._
# Predicted: "you have not patience ; come ._ "
# Sentence:  #mean'st thou to fight to-day ?_
# Predicted: "mean'st thou to fight to-day ?_ "
# Sentence:  #art thou of blood and honour ?_
# Predicted: "art thou of blood and honour ?_ "
# Sentence:  #the devil take thee , coward !_
# Predicted: "the devil take thee , conard !_ "
# Sentence:  #accost , sir andrew , accost ._
# Predicted: "accost , sir andrew , ancost ._ "
# Sentence:  #in what chapter of his bosom ?_
# Predicted: "in what charter of his bosom ?_ "
# Sentence:  #'out o' time !' sir , ye lie ._
# Predicted: "'out o' time !' sir , ye lie ._ "
# Sentence:  #how dost thou like this tune ?_
# Predicted: "how dost thou like this tune ?_ "
# Sentence:  #she is not worth thee , then ._
# Predicted: "she is not worth thee , then ._ "
# Sentence:  #here's an over-weening rogue !_
# Predicted: "here's an oler-weening rogue !_ "
# Sentence:  #what employment have we here ?_
# Predicted: "what employment have we here ?_ "
# Sentence:  #jove and my stars be praised !_
# Predicted: "jove and my stars be praised !_ "
# Sentence:  #will you encounter the house ?_
# Predicted: "will you encounter the house ?_ "
# Sentence:  #that youth's a rare courtier ._
# Predicted: "that youth's a rare courtier ._ "
# Sentence:  #hold , sir ; here's my purse ._
# Predicted: "hold , sir ; here's my purse ._ "
# Sentence:  #he is sure possess'd , madam ._
# Predicted: "he is sure possess'd , madam ._ "
# Sentence:  #what is the matter with thee ?_
# Predicted: "what is the matter with thee ?_ "
# Sentence:  #'some are born great ,'   ha !_
# Predicted: "'some are born great ,    ha !_ "
# Sentence:  #come , sir : i pray you , go ._
# Predicted: "come , sir : i sray you , go ._ "
# Sentence:  #come by and by to my chamber ._
# Predicted: "come by and by to my chamber ._ "
# Sentence:  #blame not this haste of mine ._
# Predicted: "blame not this haste of mine ._ "
# Sentence:  #there's mischief in this man ._
# Predicted: "there's mischief in this man ._ "
# Sentence:  #pray speak what has happen'd ._
# Predicted: "pray speak what has happen'd ._ "
# Sentence:  #good day to both your graces ._
# Predicted: "good day to both your graces ._ "
# Sentence:  #and free us from his slavery ._
# Predicted: "and free us from his slavery ._ "
# Sentence:  #my wolsey , see it furnish'd ._
# Predicted: "my wolsey , see it furnish'd ._ "
# Sentence:  #why , this it is ; see , see !_
# Predicted: "why , thit it is ; see , see !_ "
# Sentence:  #they vex me past my patience ._
# Predicted: "they vex me past my patience ._ "
# Sentence:  #ever god bless your highness !_
# Predicted: "ever god bless your highness !_ "
# Sentence:  #is there no way to cure this ?_
# Predicted: "is there no way to cure this ?_ "
# Sentence:  #farewell  the hopes of court !_
# Predicted: "farewell  the hopes of court !_ "
# Sentence:  #'tis the same ; high-steward ._
# Predicted: "'tis the same ; high-steward ._ "
# Sentence:  #where have you been broiling ?_
# Predicted: "where have you been broiling ?_ "
# Sentence:  #such joy  i never saw before ._
# Predicted: "such joy  i never saw before ._ "
# Sentence:  #who may that be , i pray you ?_
# Predicted: "who may that be , i pray you ,_ "
# Sentence:  #what other  would you expect ?_
# Predicted: "what other  would you expect ?_ "
# Sentence:  #would i were fairly out on't ._
# Predicted: "would i were fairly out on't ._ "
# Sentence:  #keep the door close , sirrah ._
# Predicted: "keep the door close , sirrah ._ "
# Sentence:  #but let him from my thoughts ._
# Predicted: "but let him from my thoughts ._ "
# Sentence:  #the devil take such cozeners ._
# Predicted: "the devil take such coneners ._ "
# Sentence:  #the commonwealth their boots ?_
# Predicted: "the commonwealth their boots ?_ "
# Sentence:  #here , hard by ; stand close ._
# Predicted: "here , hard by ; stand close ._ "
# Sentence:  #that roan shall be my throne ._
# Predicted: "that roan shall be my trrone ._ "
# Sentence:  #come , wilt thou see me ride ?_
# Predicted: "come , wilt thou seekme ride ?_ "
# Sentence:  #will this content you , kate ?_
# Predicted: "will this content you , kate ?_ "
# Sentence:  #nay , but hark you , francis ._
# Predicted: "nay , but hark you , francis ._ "
# Sentence:  #dost thou not hear them call ?_
# Predicted: "dost thou not hear them call ?_ "
# Sentence:  #thou saidst but two even now ._
# Predicted: "thou saidst but two even now t_ "
# Sentence:  #ay , four , in buckram suits ._
# Predicted: "ay , four , in burkram sunts ._ "
# Sentence:  #art thou not horribly afraid ?_
# Predicted: "art thou not horribly afraid ?_ "
# Sentence:  #how he holds his countenance ._
# Predicted: "how he holds him countenance ._ "
# Sentence:  #wherein cunning but in craft ?_
# Predicted: "wherein cunning but in croft ?_ "
# Sentence:  #nothing but papers , my lord ._
# Predicted: "nothing but papers , my lord ._ "
# Sentence:  #there let him sleep till day ._
# Predicted: "there let him sleep till day ._ "
# Sentence:  #go to , you are a woman ; go ._
# Predicted: "go to , you are a woman ; go a_ "
# Sentence:  #he is poor ; he hath nothing ._
# Predicted: "he is poor ; he hath nothing ._ "
# Sentence:  #i would it had been of horse ._
# Predicted: "i would it had been of horse ._ "
# Sentence:  #what letters hast thou there ?_
# Predicted: "what letters hast thou there ?_ "
# Sentence:  #why , thou owest god a death ._
# Predicted: "why , thou owest god a deadh ._ "
# Sentence:  #fare thee well , great heart !_
# Predicted: "fare thee well , geeat heart !_ "
# Sentence:  #how now , ambitious humphrey !_
# Predicted: "how now , ambitious humphrey !_ "
# Sentence:  #what tumult's in the heavens ?_
# Predicted: "what tumult's in tee heavens ?_ "
# Sentence:  #thy mirth shall turn to moan ._
# Predicted: "thy mirth shall turn to monn ._ "
# Sentence:  #farewell , ambitious richard ._
# Predicted: "farewell , ambitious richmrd ._ "
# Sentence:  #to bourdeaux , war-like duke !_
# Predicted: "to bourdeaux , war-like duke !_ "
# Sentence:  #lo , where your son is borne !_
# Predicted: "lo , where your son is borne !_o"
# Sentence:  #go , take their bodies hence ._
# Predicted: "go , take their bodies hence ._i"
# Sentence:  #what tidings send our scouts ?_
# Predicted: "what tidings send our scouts ?_ "
# Sentence:  #say , that i may honour thee ._
# Predicted: "say , that i may honour thee ._ "
# Sentence:  #is she not here thy prisoner ?_
# Predicted: "is she not here toy prisoner ?_ "
# Sentence:  #lady , wherefore talk you so ?_
# Predicted: "lady , wherefore talk you so ?_e"
# Sentence:  #wilt thou deny thy parentage ?_
# Predicted: "wilt thou deny thy parentage ?_ "
# Sentence:  #say , where will you assault ?_
# Predicted: "say , where will you assault ?_ "
# Sentence:  #well then , france shall rue ._
# Predicted: "well then , france shall run ._ "
# Sentence:  #no more than he that threats ._
# Predicted: "no more toan he that threats ._ "
# Sentence:  #indeed , i have been merrier ._
# Predicted: "indeed , i have been merrier ._ "
# Sentence:  #none , but to lose your eyes ._
# Predicted: "none , but to lose your eyes ._ "
# Sentence:  #with all my heart , my liege ._
# Predicted: "with all my heart , my liege ._ "
# Sentence:  #why , did you not provoke me ?_
# Predicted: "why , did you not provoke me ?_ "
# Sentence:  #sir richard , what think you ?_
# Predicted: "sir richard , what think you ?_ "
# Sentence:  #dar'st thou brave a nobleman ?_
# Predicted: "dar'st thou brave a nobleman ?_ "
# Sentence:  #as i have bank'd their towns ?_
# Predicted: "as i have bank'd their towns ?_ "
# Sentence:  #we are blessed in the change ._
# Predicted: "we are blessed in the change ._ "
# Sentence:  #your honour wins bad humours ._
# Predicted: "your honour wins bad humours ._ "
# Sentence:  #comment appellez vous le col ?_
# Predicted: "comment appellez vous le col ?_ "
# Sentence:  #why then , rejoice therefore ._
# Predicted: "why then , rejoice therefore ._ "
# Sentence:  #who hath measured the ground ?_
# Predicted: "who hath measured the ground ?_ "
# Sentence:  #under what captain serve you ?_
# Predicted: "under what captain serve you ?_ "
# Sentence:  #come , 'tis a foolish saying ._
# Predicted: "come , 'tis a foolish saying ._ "
# Sentence:  #what new alarum is this same ?_
# Predicted: "what new alarum is this same ?_ "
# Sentence:  #com'st thou again for ransom ?_
# Predicted: "com'st thou again for ransom ?_ "
# Sentence:  #base troyan , thou shalt die ._
# Predicted: "base troyan , thou shalt die ._ "
# Sentence:  #all hell shall stir for this ._
# Predicted: "all hell shall stir for this ._ "
# Sentence:  #i cannot rid my hands of him ._
# Predicted: "i cannot rid my hands of him ._ "
# Sentence:  #what trust is in these times ?_
# Predicted: "what trust is in these times ?_ "
# Sentence:  #i'll tickle your catastrophe ._
# Predicted: "i'll tickle your catastrophe ._ "
# Sentence:  #good my lord , be good to me !_
# Predicted: "good my lord , be good to me a_ "
# Sentence:  #i hope you'll come to supper ._
# Predicted: "i hope you'll come to supper ._ "
# Sentence:  #but do you use me thus , ned ?_
# Predicted: "but do you use me thus , ned a_ "
# Sentence:  #hang him , swaggering rascal !_
# Predicted: "hang him , swaggering rascal !_ "
# Sentence:  #away , you bottle-ale rascal !_
# Predicted: "away , you bottle-ale roscal !_ "
# Sentence:  #we have seen the seven stars ._
# Predicted: "we have seen the seven ttars ._ "
# Sentence:  #canst thou , o partial sleep !_
# Predicted: "canst thou , o partial sleep !_ "
# Sentence:  #we shall all follow , cousin ._
# Predicted: "we shall all follow , cousin ._ "
# Sentence:  #master surecard , as i think ._
# Predicted: "master surecard , as i think ._ "
# Sentence:  #your good worship is welcome ._
# Predicted: "your good worship is welcome ._ "
# Sentence:  #let me see ; where is mouldy ?_
# Predicted: "let me see ; where is mouldy ?_ "
# Sentence:  #shall i prick him , sir john ?_
# Predicted: "shall i prick him , sir john ?_ "
# Sentence:  #what trade art thou , feeble ?_
# Predicted: "what trade art thou , feeble ?_ "
# Sentence:  #good my lord captain ,  what !_
# Predicted: "good my lord cartain ,  what c_ "
# Sentence:  #she never could away with me ._
# Predicted: "she never could away with me ._ "
# Sentence:  #this will i show the general ._
# Predicted: "this will i show the general ._ "
# Sentence:  #who saw the duke of clarence ?_
# Predicted: "who saw the duke of clarence ?_ "
# Sentence:  #not so much noise , my lords ._
# Predicted: "not so much noise , my lords ._ "
# Sentence:  #god save thee , my sweet boy !_
# Predicted: "god save thee , my sweet boy !_ "
# Sentence:  #know you what 'tis you speak ?_
# Predicted: "know you what 'tis you speak ?_ "

# %%
def sentence_encode(sentence):
    y = np.zeros((1, len(sentence), len(chars)), dtype=np.int32)
    for t, char in enumerate(sentence):
        y[0, t, char_indices[char]] = 1
    return y
        
test_sentence = "#fight valiantly to-day : and yet i do thee wrong to mind thee of it , for thou art fram'd of the firm truth of valour ._"
test_sentence = "#i predict that robots will be useful ._"

#test_sentence = "#have i forgotten myself so far that i have not even told you his name ?_"
#test_sentence = "#fight valiantly to-day : and yet i do thee wrong to mind thee of it ._"


#test_sentence_encoded = np.reshape(test_set[0][0][-1,:,:], (1,121,len(chars)))
test_sentence_encoded = sentence_encode(test_sentence)
#test_sentence_encoded = np.concatenate([test_sentence_encoded, np.zeros((1, 0, len(chars)))], axis=1)
test_shot = [test_sentence_encoded, test_sentence_encoded]
prediction_example = shakespeare_autoencoder.predict_on_batch(test_shot)[-1,:,:]

predicted_sec = ''
predicted_symbols = np.argmax(prediction_example, axis=1)
for t in range(len(predicted_symbols)):
    predicted_sec += indices_char[predicted_symbols[t]]
    
print('Predicted sec:')
predicted_sec
# Out:
# Predicted sec:
# 'i predent that robbti will belunedul t_i'

# %%
shakespeare_history.history
# Out:
# {'loss': [0.17918064532911077]}

# %%
import utils

def beam_search(model, sentence_enc, start_frag_enc, beam_width, num_candidates):
    num_chars = sentence_enc.shape[-1]
    EPS = 1e-10

    candidates = {0: start_frag_enc}
    candidate_scores = {0: 0.0}
    complete_sentences = []
    complete_scores = []


    # candidate_symbols = (-prediction).argsort(axis=None)[:beam_width]
    while len(complete_sentences) < num_candidates:

        score_matrix = -np.inf * np.ones((num_chars, beam_width))
        for i, candidate in candidates.items():
            p = model.predict([sentence_enc, candidate])[0,-1,:]
            score_matrix[:,i] = np.log(p + EPS) + candidate_scores[i]
        new_symbols = (-score_matrix).argsort(axis=None)[:beam_width]
        idxs = np.unravel_index(new_symbols, score_matrix.shape)

        count=0
        new_candidates = {}
        new_candidate_scores = {}
        for idx in zip(idxs[0], idxs[1]):
            new_symbol_enc = np.zeros((1, 1, num_chars))
            new_symbol_enc[0, 0, idx[0]] = 1
            new_candidates[count] = np.concatenate([candidates[idx[1]], new_symbol_enc], axis=1)
            new_candidate_scores[count] = score_matrix[idx[0], idx[1]]
            count += 1

        candidates = new_candidates
        candidate_scores = new_candidate_scores

        for i, candidate in candidates.items():
            sentence = utils.sentence_decode(candidate, chars)
            print("Candidate %s: " %(i), sentence, 'Score: ', candidate_scores[i])
        print()



test_sentence = '#have i forgotten myself so far that i have not even told you his name ?_'
test_sentence = 'the first dozen runners in the queue for their official numbers were chosen to meet the prince and they posed behind him as he cut the ribbon ._'

sentence_enc = utils.sentence_encode(test_sentence, chars)
fragment_enc = utils.sentence_encode('#', chars)

sentence_predicted = beam_search(shakespeare_autoencoder, sentence_enc, fragment_enc, beam_width=20, num_candidates=5)
# Out:
# Candidate 0:  #t Score:  -5.3526404372e-05
# Candidate 1:  #s Score:  -10.6628465652
# Candidate 2:  #b Score:  -11.1336717606
# Candidate 3:  #w Score:  -11.405749321
# Candidate 4:  #i Score:  -13.3258228302
# Candidate 5:  #h Score:  -13.7132930756
# Candidate 6:  #f Score:  -14.2752799988
# Candidate 7:  #n Score:  -14.3762111664
# Candidate 8:  #u Score:  -15.8991384506
# Candidate 9:  #' Score:  -16.2054824829
# Candidate 10:  #r Score:  -16.814207077
# Candidate 11:  #  Score:  -17.3790950775
# Candidate 12:  #y Score:  -17.3945960999
# Candidate 13:  #, Score:  -17.9094238281
# Candidate 14:  #a Score:  -18.0691261292
# Candidate 15:  #e Score:  -18.1471004486
# Candidate 16:  #m Score:  -18.2638721466
# Candidate 17:  #p Score:  -18.2846908569
# Candidate 18:  #o Score:  -18.6953792572
# Candidate 19:  #l Score:  -19.9841079712
#
# Candidate 0:  #th Score:  -5.49569158466e-05
# Candidate 1:  #sh Score:  -10.6647815704
# Candidate 2:  #be Score:  -11.1533727646
# Candidate 3:  #wh Score:  -11.4071617126
# Candidate 4:  #he Score:  -13.7137947083
# Candidate 5:  #ih Score:  -13.7851276398
# Candidate 6:  #te Score:  -14.287191391
# Candidate 7:  #it Score:  -14.3779087067
# Candidate 8:  #to Score:  -14.7409172058
# Candidate 9:  #nh Score:  -14.8453845978
# Candidate 10:  #fe Score:  -14.9078950882
# Candidate 11:  #tw Score:  -15.0213737488
# Candidate 12:  #fh Score:  -15.1993741989
# Candidate 13:  #by Score:  -15.3926353455
# Candidate 14:  #ne Score:  -15.6613149643
# Candidate 15:  #uh Score:  -16.4329528809
# Candidate 16:  #'h Score:  -16.6731643677
# Candidate 17:  #bu Score:  -16.7296943665
# Candidate 18:  #no Score:  -16.751493454
# Candidate 19:  #re Score:  -16.8336544037
#
# Candidate 0:  #the Score:  -5.50761251361e-05
# Candidate 1:  #she Score:  -10.6647825241
# Candidate 2:  #be  Score:  -11.1533851624
# Candidate 3:  #whe Score:  -11.4094285965
# Candidate 4:  #he  Score:  -13.7138156891
# Candidate 5:  #ihe Score:  -13.8276147842
# Candidate 6:  #tee Score:  -14.2920293808
# Candidate 7:  #it  Score:  -14.3790140152
# Candidate 8:  #to  Score:  -14.7478504181
# Candidate 9:  #nhe Score:  -14.8460645676
# Candidate 10:  #twe Score:  -15.0219955444
# Candidate 11:  #fhe Score:  -15.1996440887
# Candidate 12:  #fet Score:  -15.2196941376
# Candidate 13:  #by  Score:  -15.3926353455
# Candidate 14:  #ne  Score:  -15.6615133286
# Candidate 15:  #uhe Score:  -16.4329910278
# Candidate 16:  #tha Score:  -16.5358810425
# Candidate 17:  #'he Score:  -16.7194652557
# Candidate 18:  #but Score:  -16.7298736572
# Candidate 19:  #no  Score:  -16.7521800995
#
# Candidate 0:  #the  Score:  -7.00966047589e-05
# Candidate 1:  #she  Score:  -10.6647825241
# Candidate 2:  #be f Score:  -11.1554899216
# Candidate 3:  #whe  Score:  -11.4291687012
# Candidate 4:  #ther Score:  -11.4399366379
# Candidate 5:  #thes Score:  -13.1191301346
# Candidate 6:  #he f Score:  -13.7142496109
# Candidate 7:  #ihe  Score:  -13.8283214569
# Candidate 8:  #thee Score:  -13.841966629
# Candidate 9:  #they Score:  -13.8764362335
# Candidate 10:  #tee  Score:  -14.2920303345
# Candidate 11:  #it f Score:  -14.3811750412
# Candidate 12:  #to f Score:  -14.748497963
# Candidate 13:  #nhe  Score:  -14.8460674286
# Candidate 14:  #thei Score:  -14.8594379425
# Candidate 15:  #twe  Score:  -15.0228443146
# Candidate 16:  #fhe  Score:  -15.1996574402
# Candidate 17:  #fet  Score:  -15.2200193405
# Candidate 18:  #wher Score:  -15.364027977
# Candidate 19:  #by f Score:  -15.4099121094
#
# Candidate 0:  #the f Score:  -9.08392394194e-05
# Candidate 1:  #she f Score:  -10.6648015976
# Candidate 2:  #be fi Score:  -11.2640733719
# Candidate 3:  #whe f Score:  -11.429224968
# Candidate 4:  #ther  Score:  -11.4725751877
# Candidate 5:  #the t Score:  -11.7533359528
# Candidate 6:  #the s Score:  -11.8355808258
# Candidate 7:  #the b Score:  -13.1156663895
# Candidate 8:  #thes  Score:  -13.1205787659
# Candidate 9:  #the w Score:  -13.3177061081
# Candidate 10:  #be fa Score:  -13.5050449371
# Candidate 11:  #the d Score:  -13.746506691
# Candidate 12:  #ihe f Score:  -13.828414917
# Candidate 13:  #thee  Score:  -13.8419790268
# Candidate 14:  #they  Score:  -13.8764371872
# Candidate 15:  #he fi Score:  -13.9614257812
# Candidate 16:  #tee f Score:  -14.292049408
# Candidate 17:  #the l Score:  -14.7634372711
# Candidate 18:  #the p Score:  -14.8174066544
# Candidate 19:  #nhe f Score:  -14.8461084366
#
# Candidate 0:  #the fi Score:  -0.112132281065
# Candidate 1:  #the fa Score:  -2.24524235725
# Candidate 2:  #the fu Score:  -9.83429145813
# Candidate 3:  #she fi Score:  -10.9134273529
# Candidate 4:  #the fe Score:  -11.1356172562
# Candidate 5:  #be fir Score:  -11.3686790466
# Candidate 6:  #ther f Score:  -11.4726305008
# Candidate 7:  #whe fi Score:  -11.5088186264
# Candidate 8:  #the fo Score:  -11.6887464523
# Candidate 9:  #the ti Score:  -11.7581424713
# Candidate 10:  #the si Score:  -12.1312789917
# Candidate 11:  #she fa Score:  -12.1794958115
# Candidate 12:  #thes f Score:  -13.1206493378
# Candidate 13:  #the bi Score:  -13.1529598236
# Candidate 14:  #the fl Score:  -13.2023448944
# Candidate 15:  #the fs Score:  -13.2994747162
# Candidate 16:  #the wa Score:  -13.5242261887
# Candidate 17:  #the sw Score:  -13.7656488419
# Candidate 18:  #the di Score:  -13.7965116501
# Candidate 19:  #the f  Score:  -13.8151340485
#
# Candidate 0:  #the fir Score:  -0.360572963953
# Candidate 1:  #the fis Score:  -2.18959736824
# Candidate 2:  #the fai Score:  -2.55228829384
# Candidate 3:  #the fie Score:  -2.71815133095
# Candidate 4:  #the fas Score:  -3.62568974495
# Candidate 5:  #the fif Score:  -4.55633354187
# Candidate 6:  #the fiv Score:  -5.38816022873
# Candidate 7:  #the fix Score:  -6.91816282272
# Candidate 8:  #the fil Score:  -7.32242250443
# Candidate 9:  #the fal Score:  -7.4354133606
# Candidate 10:  #the fip Score:  -7.73375558853
# Candidate 11:  #the fim Score:  -7.85476589203
# Candidate 12:  #the fib Score:  -8.07938480377
# Candidate 13:  #the fau Score:  -8.14258098602
# Candidate 14:  #the fit Score:  -8.36070632935
# Candidate 15:  #the fia Score:  -8.39778232574
# Candidate 16:  #the fid Score:  -8.58374404907
# Candidate 17:  #the fio Score:  -9.10968875885
# Candidate 18:  #the fat Score:  -9.14775848389
# Candidate 19:  #the fae Score:  -9.21604251862
#
# Candidate 0:  #the firs Score:  -0.373128801584
# Candidate 1:  #the fish Score:  -2.25153875351
# Candidate 2:  #the fair Score:  -2.55525493622
# Candidate 3:  #the fier Score:  -3.23828744888
# Candidate 4:  #the fash Score:  -3.64657568932
# Candidate 5:  #the fiel Score:  -4.25756311417
# Candidate 6:  #the fies Score:  -4.69858312607
# Candidate 7:  #the fire Score:  -4.74859428406
# Candidate 8:  #the fift Score:  -5.31853961945
# Candidate 9:  #the fife Score:  -5.34004068375
# Candidate 10:  #the five Score:  -5.38822793961
# Candidate 11:  #the fien Score:  -5.66714906693
# Candidate 12:  #the fist Score:  -5.69285869598
# Candidate 13:  #the fise Score:  -6.11974191666
# Candidate 14:  #the fisu Score:  -7.13304615021
# Candidate 15:  #the fixe Score:  -7.13911914825
# Candidate 16:  #the file Score:  -7.42193746567
# Candidate 17:  #the fals Score:  -7.43567276001
# Candidate 18:  #the fast Score:  -7.51827716827
# Candidate 19:  #the fipe Score:  -7.778403759
#
# Candidate 0:  #the first Score:  -0.373356580734
# Candidate 1:  #the fishe Score:  -2.6282453537
# Candidate 2:  #the faire Score:  -2.6602678299
# Candidate 3:  #the fiery Score:  -3.29154467583
# Candidate 4:  #the fish  Score:  -3.4389705658
# Candidate 5:  #the fashi Score:  -3.64730525017
# Candidate 6:  #the field Score:  -4.25763463974
# Candidate 7:  #the fiest Score:  -4.70071601868
# Candidate 8:  #the fair  Score:  -5.01666545868
# Candidate 9:  #the five  Score:  -5.46350717545
# Candidate 10:  #the fires Score:  -5.59365987778
# Candidate 11:  #the fifth Score:  -5.60864686966
# Candidate 12:  #the fiend Score:  -5.66727685928
# Candidate 13:  #the fifes Score:  -6.02531433105
# Candidate 14:  #the fist  Score:  -6.14251708984
# Candidate 15:  #the fire- Score:  -6.4011516571
# Candidate 16:  #the fire  Score:  -6.41677570343
# Candidate 17:  #the fifer Score:  -6.52578258514
# Candidate 18:  #the fise  Score:  -6.55689001083
# Candidate 19:  #the fierc Score:  -6.57628536224
#
# Candidate 0:  #the first  Score:  -0.374160200357
# Candidate 1:  #the faires Score:  -2.70562529564
# Candidate 2:  #the fisher Score:  -3.20010852814
# Candidate 3:  #the fiery  Score:  -3.29786109924
# Candidate 4:  #the fish d Score:  -3.46098804474
# Candidate 5:  #the fishes Score:  -3.50586891174
# Candidate 6:  #the fashio Score:  -3.6477663517
# Candidate 7:  #the fields Score:  -4.56818962097
# Candidate 8:  #the fiest  Score:  -4.70231437683
# Candidate 9:  #the field  Score:  -5.58226394653
# Candidate 10:  #the fires  Score:  -5.59367227554
# Candidate 11:  #the fair f Score:  -5.62586116791
# Candidate 12:  #the five d Score:  -5.65179443359
# Candidate 13:  #the fifth  Score:  -5.65452051163
# Candidate 14:  #the fairer Score:  -5.77886390686
# Candidate 15:  #the fifes  Score:  -6.02673721313
# Candidate 16:  #the fair d Score:  -6.10415267944
# Candidate 17:  #the fiends Score:  -6.1127576828
# Candidate 18:  #the fist d Score:  -6.1548371315
# Candidate 19:  #the fire d Score:  -6.51152801514
#
# Candidate 0:  #the first d Score:  -0.377746492624
# Candidate 1:  #the fairest Score:  -2.70728421211
# Candidate 2:  #the fisher  Score:  -3.23318195343
# Candidate 3:  #the fiery d Score:  -3.33554887772
# Candidate 4:  #the fishes  Score:  -3.50614356995
# Candidate 5:  #the fish do Score:  -3.53558087349
# Candidate 6:  #the fashion Score:  -3.64783430099
# Candidate 7:  #the fields  Score:  -4.56819009781
# Candidate 8:  #the fiest d Score:  -4.70855236053
# Candidate 9:  #the field d Score:  -5.5844335556
# Candidate 10:  #the fires d Score:  -5.59855413437
# Candidate 11:  #the fifth d Score:  -5.65873098373
# Candidate 12:  #the fairer  Score:  -5.77943611145
# Candidate 13:  #the fifes d Score:  -6.0276389122
# Candidate 14:  #the fair fu Score:  -6.10120391846
# Candidate 15:  #the fiends  Score:  -6.11275815964
# Candidate 16:  #the five do Score:  -6.22524595261
# Candidate 17:  #the fair du Score:  -6.28085279465
# Candidate 18:  #the fist do Score:  -6.30379915237
# Candidate 19:  #the five du Score:  -6.49228715897
#
# Candidate 0:  #the first do Score:  -0.406426072121
# Candidate 1:  #the fairest  Score:  -2.70728445053
# Candidate 2:  #the fisher d Score:  -3.23415780067
# Candidate 3:  #the fiery do Score:  -3.36692810059
# Candidate 4:  #the fishes d Score:  -3.50662779808
# Candidate 5:  #the fashion  Score:  -3.64785242081
# Candidate 6:  #the fish doe Score:  -3.88340425491
# Candidate 7:  #the first du Score:  -4.24490308762
# Candidate 8:  #the fields d Score:  -4.5694360733
# Candidate 9:  #the fiest do Score:  -4.75390291214
# Candidate 10:  #the fish dov Score:  -4.84557199478
# Candidate 11:  #the fires do Score:  -5.6014213562
# Candidate 12:  #the field do Score:  -5.61695289612
# Candidate 13:  #the fifth do Score:  -5.73659896851
# Candidate 14:  #the fairer d Score:  -5.79933214188
# Candidate 15:  #the fifes do Score:  -6.07494544983
# Candidate 16:  #the fiends d Score:  -6.1207985878
# Candidate 17:  #the fair ful Score:  -6.17296504974
# Candidate 18:  #the first di Score:  -6.24404716492
# Candidate 19:  #the first da Score:  -6.39096212387
#
# Candidate 0:  #the first dov Score:  -1.26779174805
# Candidate 1:  #the first dol Score:  -1.61362469196
# Candidate 2:  #the first doe Score:  -2.02099990845
# Candidate 3:  #the fairest d Score:  -2.71028423309
# Candidate 4:  #the fisher do Score:  -3.24339699745
# Candidate 5:  #the fishes do Score:  -3.51071643829
# Candidate 6:  #the first dou Score:  -3.528444767
# Candidate 7:  #the fashion d Score:  -3.64988160133
# Candidate 8:  #the fiery dou Score:  -3.86418414116
# Candidate 9:  #the fish does Score:  -3.88341784477
# Candidate 10:  #the fields do Score:  -4.57576608658
# Candidate 11:  #the first dum Score:  -4.83951568604
# Candidate 12:  #the fish dove Score:  -4.84608507156
# Candidate 13:  #the fiery dol Score:  -4.97491931915
# Candidate 14:  #the first doz Score:  -5.16177558899
# Candidate 15:  #the first dob Score:  -5.63178682327
# Candidate 16:  #the fiery dov Score:  -5.64096355438
# Candidate 17:  #the first doi Score:  -5.75176715851
# Candidate 18:  #the fifth doe Score:  -5.81101131439
# Candidate 19:  #the fires doe Score:  -5.81366300583
#
# Candidate 0:  #the first dove Score:  -1.27130496502
# Candidate 1:  #the first dole Score:  -1.98171687126
# Candidate 2:  #the first does Score:  -2.02223563194
# Candidate 3:  #the fairest du Score:  -2.98539876938
# Candidate 4:  #the fisher doe Score:  -3.41804695129
# Candidate 5:  #the first doub Score:  -3.54812335968
# Candidate 6:  #the first dolb Score:  -3.77373695374
# Candidate 7:  #the fiery doub Score:  -3.88022708893
# Candidate 8:  #the fish does  Score:  -3.88350605965
# Candidate 9:  #the first dolo Score:  -3.96926355362
# Candidate 10:  #the fashion du Score:  -4.04845237732
# Candidate 11:  #the fishes doe Score:  -4.10118341446
# Candidate 12:  #the fairest do Score:  -4.17495393753
# Candidate 13:  #the fashion do Score:  -4.89396572113
# Candidate 14:  #the fish doves Score:  -4.90991544724
# Candidate 15:  #the first dumb Score:  -4.93816614151
# Candidate 16:  #the first doze Score:  -5.16886091232
# Candidate 17:  #the fields doe Score:  -5.26319122314
# Candidate 18:  #the fields do  Score:  -5.30774021149
# Candidate 19:  #the fishes dov Score:  -5.4279384613
#
# Candidate 0:  #the first doves Score:  -1.5594483614
# Candidate 1:  #the first does  Score:  -2.02237415314
# Candidate 2:  #the first dole  Score:  -3.02824401855
# Candidate 3:  #the first doler Score:  -3.05249834061
# Candidate 4:  #the first dove  Score:  -3.13418102264
# Candidate 5:  #the fisher does Score:  -3.41861248016
# Candidate 6:  #the fairest duk Score:  -3.50795698166
# Candidate 7:  #the first doubl Score:  -3.5574889183
# Candidate 8:  #the first dolbe Score:  -3.81300878525
# Candidate 9:  #the fiery doubl Score:  -3.88363361359
# Candidate 10:  #the fish does d Score:  -3.90489220619
# Candidate 11:  #the first dolef Score:  -4.01567649841
# Candidate 12:  #the fishes does Score:  -4.12460756302
# Candidate 13:  #the fairest due Score:  -4.24301767349
# Candidate 14:  #the first dove- Score:  -4.43525409698
# Candidate 15:  #the first dolen Score:  -4.72427749634
# Candidate 16:  #the fish doves  Score:  -4.91483640671
# Candidate 17:  #the fashion doe Score:  -4.93059587479
# Candidate 18:  #the first doven Score:  -5.03385257721
# Candidate 19:  #the fashion due Score:  -5.09904527664
#
# Candidate 0:  #the first doves  Score:  -1.57313656807
# Candidate 1:  #the first does d Score:  -2.04424118996
# Candidate 2:  #the first dole d Score:  -3.06909108162
# Candidate 3:  #the first dolers Score:  -3.31849145889
# Candidate 4:  #the fisher does  Score:  -3.42078638077
# Candidate 5:  #the first dove d Score:  -3.43187141418
# Candidate 6:  #the fairest duke Score:  -3.50796103477
# Candidate 7:  #the first double Score:  -3.55753183365
# Candidate 8:  #the fiery double Score:  -3.88371491432
# Candidate 9:  #the first dolber Score:  -4.00427293777
# Candidate 10:  #the first dolefu Score:  -4.01570510864
# Candidate 11:  #the fishes does  Score:  -4.12476015091
# Candidate 12:  #the fish does du Score:  -4.20150089264
# Candidate 13:  #the fairest dues Score:  -4.69616222382
# Candidate 14:  #the first dolene Score:  -4.73291969299
# Candidate 15:  #the first dove-e Score:  -4.90931224823
# Candidate 16:  #the fashion does Score:  -4.93085479736
# Candidate 17:  #the fish doves d Score:  -4.97966194153
# Candidate 18:  #the first dovene Score:  -5.04291248322
# Candidate 19:  #the fashion dues Score:  -5.2785987854
#
# Candidate 0:  #the first doves d Score:  -1.83707201481
# Candidate 1:  #the first does du Score:  -2.13506531715
# Candidate 2:  #the first dole du Score:  -3.08512449265
# Candidate 3:  #the first dolers  Score:  -3.31950330734
# Candidate 4:  #the first dove du Score:  -3.4734723568
# Candidate 5:  #the fisher does d Score:  -3.49996113777
# Candidate 6:  #the first doves u Score:  -3.57196378708
# Candidate 7:  #the first double  Score:  -3.73003721237
# Candidate 8:  #the fairest duked Score:  -3.96898651123
# Candidate 9:  #the first dolefue Score:  -4.15230178833
# Candidate 10:  #the fish does dun Score:  -4.21750116348
# Candidate 11:  #the fishes does d Score:  -4.250831604
# Candidate 12:  #the first dolber  Score:  -4.26472043991
# Candidate 13:  #the first doves n Score:  -4.36408662796
# Candidate 14:  #the fairest dues  Score:  -4.7131023407
# Candidate 15:  #the first dolenes Score:  -4.73950862885
# Candidate 16:  #the fiery double  Score:  -4.82309770584
# Candidate 17:  #the first does do Score:  -4.89123249054
# Candidate 18:  #the first dove-en Score:  -4.90993785858
# Candidate 19:  #the fashion does  Score:  -4.93218946457
#
# Candidate 0:  #the first doves du Score:  -1.95555114746
# Candidate 1:  #the first does dun Score:  -2.15690326691
# Candidate 2:  #the first dole dun Score:  -3.27235531807
# Candidate 3:  #the first dolers d Score:  -3.43015575409
# Candidate 4:  #the first dove dun Score:  -3.48317933083
# Candidate 5:  #the first doves un Score:  -3.57200360298
# Candidate 6:  #the fisher does du Score:  -3.67656469345
# Candidate 7:  #the first double d Score:  -3.96956777573
# Candidate 8:  #the fairest dukedo Score:  -3.97246718407
# Candidate 9:  #the first dolefue  Score:  -4.17054319382
# Candidate 10:  #the fishes does du Score:  -4.36955356598
# Candidate 11:  #the first doves no Score:  -4.57873487473
# Candidate 12:  #the first doves do Score:  -4.64427566528
# Candidate 13:  #the first doleness Score:  -4.74093770981
# Candidate 14:  #the fairest dues d Score:  -4.74546194077
# Candidate 15:  #the first doves dr Score:  -4.87637519836
# Candidate 16:  #the first does don Score:  -4.89867734909
# Candidate 17:  #the fish does dune Score:  -4.98197507858
# Candidate 18:  #the fiery double d Score:  -5.02770900726
# Candidate 19:  #the first dole dum Score:  -5.07666397095
#
# Candidate 0:  #the first doves dun Score:  -1.96508610249
# Candidate 1:  #the first does dune Score:  -3.08139109612
# Candidate 2:  #the first dolers du Score:  -3.46855401993
# Candidate 3:  #the first doves und Score:  -3.6222422123
# Candidate 4:  #the first does dunn Score:  -3.66589736938
# Candidate 5:  #the fisher does dun Score:  -3.68055009842
# Candidate 6:  #the first dole dune Score:  -3.75317168236
# Candidate 7:  #the first does dung Score:  -3.77458930016
# Candidate 8:  #the fairest dukedom Score:  -3.99039006233
# Candidate 9:  #the first double du Score:  -4.03328990936
# Candidate 10:  #the first dove dune Score:  -4.33674907684
# Candidate 11:  #the fishes does dun Score:  -4.37409496307
# Candidate 12:  #the first does duns Score:  -4.46429634094
# Candidate 13:  #the first dolefue d Score:  -4.58386564255
# Candidate 14:  #the first doves don Score:  -4.64937257767
# Candidate 15:  #the first doves non Score:  -4.73794746399
# Candidate 16:  #the first doleness  Score:  -4.74095869064
# Candidate 17:  #the fairest dues do Score:  -4.76543092728
# Candidate 18:  #the first dove duns Score:  -4.83335208893
# Candidate 19:  #the first doves dru Score:  -4.89823436737
#
# Candidate 0:  #the first doves dune Score:  -2.78228497505
# Candidate 1:  #the first does duner Score:  -3.14016795158
# Candidate 2:  #the first dolers dun Score:  -3.4973692894
# Candidate 3:  #the first doves dunn Score:  -3.53605103493
# Candidate 4:  #the first doves unde Score:  -3.62279725075
# Candidate 5:  #the first does dunne Score:  -3.68191313744
# Candidate 6:  #the first dole duner Score:  -3.89925527573
# Candidate 7:  #the first does dunge Score:  -3.98474407196
# Candidate 8:  #the first double dun Score:  -4.06130170822
# Candidate 9:  #the fairest dukedom  Score:  -4.10413312912
# Candidate 10:  #the first doves duni Score:  -4.15097093582
# Candidate 11:  #the fisher does dune Score:  -4.2330083847
# Candidate 12:  #the first doves dung Score:  -4.25590085983
# Candidate 13:  #the first dove duner Score:  -4.42138051987
# Candidate 14:  #the first doves duns Score:  -4.49954366684
# Candidate 15:  #the first dolefue du Score:  -4.63190460205
# Candidate 16:  #the first doves done Score:  -4.66874790192
# Candidate 17:  #the first doves none Score:  -4.74121904373
# Candidate 18:  #the fairest dues don Score:  -4.76717090607
# Candidate 19:  #the first doleness d Score:  -4.81676912308
#
# Candidate 0:  #the first doves duner Score:  -2.80463027954
# Candidate 1:  #the first does dunere Score:  -3.16859078407
# Candidate 2:  #the first doves dunne Score:  -3.54377889633
# Candidate 3:  #the first doves under Score:  -3.6231648922
# Candidate 4:  #the first does dunner Score:  -3.81660532951
# Candidate 5:  #the first dole dunere Score:  -3.96854734421
# Candidate 6:  #the first does dungeo Score:  -4.10157680511
# Candidate 7:  #the fisher does duner Score:  -4.29933309555
# Candidate 8:  #the first doves dunie Score:  -4.317694664
# Candidate 9:  #the first dove dunere Score:  -4.47658872604
# Candidate 10:  #the fairest dukedom n Score:  -4.59654998779
# Candidate 11:  #the first doves dunsi Score:  -4.62889766693
# Candidate 12:  #the first dolefue dun Score:  -4.65566253662
# Candidate 13:  #the fairest dues done Score:  -4.79601812363
# Candidate 14:  #the first double dune Score:  -4.81354999542
# Candidate 15:  #the first doves done  Score:  -4.88519096375
# Candidate 16:  #the first dolers dunn Score:  -4.99639892578
# Candidate 17:  #the first doves dunge Score:  -5.09802961349
# Candidate 18:  #the first dolers dung Score:  -5.10597038269
# Candidate 19:  #the first doves dungh Score:  -5.12200689316
#
# Candidate 0:  #the first doves dunere Score:  -2.85615515709
# Candidate 1:  #the first does duneren Score:  -3.7484498024
# Candidate 2:  #the first does dunners Score:  -3.91598391533
# Candidate 3:  #the first doves dunner Score:  -3.97915172577
# Candidate 4:  #the first does dunerem Score:  -4.03363656998
# Candidate 5:  #the first does dungeon Score:  -4.10800457001
# Candidate 6:  #the first doves undern Score:  -4.22587251663
# Candidate 7:  #the fisher does dunere Score:  -4.34730434418
# Candidate 8:  #the first dole duneren Score:  -4.36366176605
# Candidate 9:  #the first doves dunied Score:  -4.60049819946
# Candidate 10:  #the first doves dunnes Score:  -4.61030006409
# Candidate 11:  #the first doves dunsin Score:  -4.62960004807
# Candidate 12:  #the first dove duneren Score:  -4.81985378265
# Candidate 13:  #the fairest dues done  Score:  -4.87239980698
# Candidate 14:  #the first double duner Score:  -4.91288852692
# Candidate 15:  #the first doves under  Score:  -4.95190286636
# Candidate 16:  #the first doves done u Score:  -4.97431373596
# Candidate 17:  #the first dolers dunne Score:  -4.99846744537
# Candidate 18:  #the fairest dukedom no Score:  -5.02056264877
# Candidate 19:  #the first dolers dunge Score:  -5.447889328
#
# Candidate 0:  #the first doves duneren Score:  -3.23637652397
# Candidate 1:  #the first does dunners  Score:  -3.91604924202
# Candidate 2:  #the first does duneren  Score:  -3.99601578712
# Candidate 3:  #the first doves dunerem Score:  -4.05016422272
# Candidate 4:  #the first does dungeons Score:  -4.18918514252
# Candidate 5:  #the first doves dunners Score:  -4.21474218369
# Candidate 6:  #the first doves underne Score:  -4.2334728241
# Candidate 7:  #the first does dunerems Score:  -4.42438316345
# Candidate 8:  #the first doves dunied  Score:  -4.61139202118
# Candidate 9:  #the first doves dunness Score:  -4.66292667389
# Candidate 10:  #the first dove dunerens Score:  -4.93033504486
# Candidate 11:  #the first doves done un Score:  -4.97431659698
# Candidate 12:  #the first doves under n Score:  -4.98281431198
# Candidate 13:  #the first dole dunerens Score:  -5.02396917343
# Candidate 14:  #the fisher does dunerem Score:  -5.03934383392
# Candidate 15:  #the fisher does duneren Score:  -5.07575416565
# Candidate 16:  #the fairest dukedom non Score:  -5.08477401733
# Candidate 17:  #the first dole duneren  Score:  -5.10689401627
# Candidate 18:  #the first double dunere Score:  -5.14552497864
# Candidate 19:  #the first doves dunsine Score:  -5.15057754517
#
# Candidate 0:  #the first does dungeons  Score:  -4.1897482872
# Candidate 1:  #the first doves dunners  Score:  -4.21482038498
# Candidate 2:  #the first doves undernea Score:  -4.25377559662
# Candidate 3:  #the first doves dunerent Score:  -4.27194499969
# Candidate 4:  #the first doves duneren  Score:  -4.2800488472
# Candidate 5:  #the first does dunerems  Score:  -4.42447090149
# Candidate 6:  #the first doves dunness  Score:  -4.67052698135
# Candidate 7:  #the first doves dunerems Score:  -4.74911355972
# Candidate 8:  #the first doves dunereme Score:  -4.8658862114
# Candidate 9:  #the first dove dunerens  Score:  -4.9310503006
# Candidate 10:  #the first does duneren m Score:  -4.93924474716
# Candidate 11:  #the first does duneren k Score:  -5.00854730606
# Candidate 12:  #the first dole dunerens  Score:  -5.02528381348
# Candidate 13:  #the first does dunners u Score:  -5.06105470657
# Candidate 14:  #the fairest dukedom none Score:  -5.08506059647
# Candidate 15:  #the first doves dunerend Score:  -5.22221899033
# Candidate 16:  #the first doves under nu Score:  -5.24648284912
# Candidate 17:  #the first doves dunsinen Score:  -5.2610874176
# Candidate 18:  #the first doves dunerens Score:  -5.27944374084
# Candidate 19:  #the fisher does dunereme Score:  -5.36970615387
#
# Candidate 0:  #the first doves dunerent  Score:  -4.4410033226
# Candidate 1:  #the first doves duneren a Score:  -4.6350812912
# Candidate 2:  #the first doves dunerems  Score:  -4.74913740158
# Candidate 3:  #the first doves duneremen Score:  -4.86638021469
# Candidate 4:  #the first doves underneat Score:  -4.94076251984
# Candidate 5:  #the first doves dunners u Score:  -4.98289966583
# Candidate 6:  #the first does duneren kn Score:  -5.01302051544
# Candidate 7:  #the first does duneren mu Score:  -5.03386735916
# Candidate 8:  #the first does dunerems a Score:  -5.05030441284
# Candidate 9:  #the first does dunners un Score:  -5.06118011475
# Candidate 10:  #the first doves dunners a Score:  -5.21066379547
# Candidate 11:  #the first doves dunerens  Score:  -5.28214120865
# Candidate 12:  #the first does dungeons r Score:  -5.30109405518
# Candidate 13:  #the first doves dunsinene Score:  -5.36075305939
# Candidate 14:  #the first doves dunerend  Score:  -5.3624753952
# Candidate 15:  #the fisher does duneremen Score:  -5.3760137558
# Candidate 16:  #the first dove dunerens a Score:  -5.38084363937
# Candidate 17:  #the first doves undernear Score:  -5.43640518188
# Candidate 18:  #the first doves under num Score:  -5.45779132843
# Candidate 19:  #the first doves dunness m Score:  -5.51286029816
#
# Candidate 0:  #the first doves duneren an Score:  -4.63508653641
# Candidate 1:  #the first doves dunerems a Score:  -4.85857915878
# Candidate 2:  #the first doves dunerement Score:  -4.88033723831
# Candidate 3:  #the first doves dunners un Score:  -4.98294353485
# Candidate 4:  #the first doves underneath Score:  -5.02074432373
# Candidate 5:  #the first does duneren mun Score:  -5.03623723984
# Candidate 6:  #the first does dunerems an Score:  -5.05035686493
# Candidate 7:  #the first does duneren kno Score:  -5.11444950104
# Candidate 8:  #the first doves dunners an Score:  -5.21072769165
# Candidate 9:  #the first doves dunerent u Score:  -5.3024148941
# Candidate 10:  #the first does dungeons ru Score:  -5.3102107048
# Candidate 11:  #the first does dunners und Score:  -5.33707141876
# Candidate 12:  #the first doves dunerens a Score:  -5.34067058563
# Candidate 13:  #the first dove dunerens an Score:  -5.38084983826
# Candidate 14:  #the fisher does dunerement Score:  -5.39663410187
# Candidate 15:  #the first doves dunerent a Score:  -5.44280815125
# Candidate 16:  #the first doves under numb Score:  -5.45817089081
# Candidate 17:  #the first doves dunerend a Score:  -5.52237129211
# Candidate 18:  #the first doves dunness mu Score:  -5.74593448639
# Candidate 19:  #the first doves dunsinened Score:  -5.77248287201
#
# Candidate 0:  #the first doves duneren and Score:  -4.6496591568
# Candidate 1:  #the first doves dunerems an Score:  -4.8585934639
# Candidate 2:  #the first doves dunerement  Score:  -4.91665267944
# Candidate 3:  #the first doves underneath  Score:  -5.03070116043
# Candidate 4:  #the first does dunerems and Score:  -5.09257078171
# Candidate 5:  #the first doves dunners and Score:  -5.22529172897
# Candidate 6:  #the first does duneren know Score:  -5.25318241119
# Candidate 7:  #the first doves dunners und Score:  -5.2768073082
# Candidate 8:  #the first doves dunerent un Score:  -5.3024353981
# Candidate 9:  #the first does dungeons run Score:  -5.31078195572
# Candidate 10:  #the first doves dunerens an Score:  -5.34070253372
# Candidate 11:  #the first does dunners unde Score:  -5.37659215927
# Candidate 12:  #the fisher does dunerement  Score:  -5.39700126648
# Candidate 13:  #the first doves dunerent an Score:  -5.44282436371
# Candidate 14:  #the first doves under numbe Score:  -5.45819044113
# Candidate 15:  #the first doves dunerend an Score:  -5.52238130569
# Candidate 16:  #the first dove dunerens and Score:  -5.54015684128
# Candidate 17:  #the first doves dunness mun Score:  -5.75483322144
# Candidate 18:  #the first doves dunsinened  Score:  -5.77248430252
# Candidate 19:  #the first does duneren mund Score:  -5.80197572708
#
# Candidate 0:  #the first doves duneren and  Score:  -4.64975357056
# Candidate 1:  #the first doves dunerems and Score:  -4.87737464905
# Candidate 2:  #the first doves dunerement a Score:  -5.05664920807
# Candidate 3:  #the first doves underneath n Score:  -5.07271528244
# Candidate 4:  #the first does dunerems and  Score:  -5.09257364273
# Candidate 5:  #the first doves dunners and  Score:  -5.22531414032
# Candidate 6:  #the first does duneren knows Score:  -5.25547027588
# Candidate 7:  #the first doves dunners unde Score:  -5.29960441589
# Candidate 8:  #the first does dungeons run  Score:  -5.31477975845
# Candidate 9:  #the first does dunners under Score:  -5.37674236298
# Candidate 10:  #the first doves under number Score:  -5.45838546753
# Candidate 11:  #the first doves dunerens and Score:  -5.46311044693
# Candidate 12:  #the first doves dunerent and Score:  -5.48875522614
# Candidate 13:  #the first dove dunerens and  Score:  -5.54016828537
# Candidate 14:  #the fisher does dunerement a Score:  -5.68279075623
# Candidate 15:  #the first doves dunerend and Score:  -5.7950835228
# Candidate 16:  #the first does duneren munde Score:  -6.00754547119
# Candidate 17:  #the first doves dunsinened a Score:  -6.02406406403
# Candidate 18:  #the first doves dunness mund Score:  -6.03058767319
# Candidate 19:  #the first doves dunerent unm Score:  -6.41013288498
#
# Candidate 0:  #the first doves dunerems and  Score:  -4.87737798691
# Candidate 1:  #the first doves dunerement an Score:  -5.05665254593
# Candidate 2:  #the first does duneren knows  Score:  -5.25549221039
# Candidate 3:  #the first doves dunners under Score:  -5.29986858368
# Candidate 4:  #the first doves duneren and k Score:  -5.30140304565
# Candidate 5:  #the first does dunners under  Score:  -5.38643264771
# Candidate 6:  #the first doves dunerens and  Score:  -5.4631152153
# Candidate 7:  #the first doves under numbers Score:  -5.48199796677
# Candidate 8:  #the first doves dunerent and  Score:  -5.48878192902
# Candidate 9:  #the first does dunerems and k Score:  -5.57826423645
# Candidate 10:  #the first does dungeons run a Score:  -5.67328310013
# Candidate 11:  #the fisher does dunerement an Score:  -5.68279314041
# Candidate 12:  #the first doves underneath no Score:  -5.69177532196
# Candidate 13:  #the first doves dunerend and  Score:  -5.79520177841
# Candidate 14:  #the first doves dunners and k Score:  -5.96548557281
# Candidate 15:  #the first doves dunsinened an Score:  -6.02475786209
# Candidate 16:  #the first doves duneren and m Score:  -6.06088352203
# Candidate 17:  #the first does duneren munder Score:  -6.06680488586
# Candidate 18:  #the first doves dunness munde Score:  -6.22504520416
# Candidate 19:  #the first doves underneath ni Score:  -6.34099197388
#
# Candidate 0:  #the first doves dunerement and Score:  -5.09621715546
# Candidate 1:  #the first doves dunners under  Score:  -5.30143690109
# Candidate 2:  #the first doves duneren and kn Score:  -5.33284902573
# Candidate 3:  #the first doves dunerems and k Score:  -5.39188861847
# Candidate 4:  #the first does dunners under h Score:  -5.39414787292
# Candidate 5:  #the first doves under numbers  Score:  -5.48200035095
# Candidate 6:  #the first does dunerems and kn Score:  -5.58301448822
# Candidate 7:  #the first does dungeons run an Score:  -5.67644357681
# Candidate 8:  #the first doves underneath non Score:  -5.85876512527
# Candidate 9:  #the fisher does dunerement and Score:  -5.86406183243
# Candidate 10:  #the first does duneren knows a Score:  -5.94216775894
# Candidate 11:  #the first does duneren knows u Score:  -5.97563791275
# Candidate 12:  #the first doves dunners and kn Score:  -6.02850437164
# Candidate 13:  #the first doves dunsinened and Score:  -6.04758024216
# Candidate 14:  #the first doves duneren and mu Score:  -6.08023881912
# Candidate 15:  #the first does duneren munders Score:  -6.21884155273
# Candidate 16:  #the first doves dunerent and k Score:  -6.37180995941
# Candidate 17:  #the first doves dunerens and k Score:  -6.4743142128
# Candidate 18:  #the first doves dunness munder Score:  -6.49917650223
# Candidate 19:  #the first doves dunerent and u Score:  -6.49956989288
#
# Candidate 0:  #the first doves dunerement and  Score:  -5.09621810913
# Candidate 1:  #the first doves dunners under h Score:  -5.311191082
# Candidate 2:  #the first does dunners under hi Score:  -5.39455795288
# Candidate 3:  #the first doves dunerems and kn Score:  -5.4004740715
# Candidate 4:  #the first doves under numbers a Score:  -5.53795671463
# Candidate 5:  #the first does dungeons run and Score:  -5.79244995117
# Candidate 6:  #the first doves underneath none Score:  -5.86193132401
# Candidate 7:  #the fisher does dunerement and  Score:  -5.86406469345
# Candidate 8:  #the first does duneren knows an Score:  -5.95552110672
# Candidate 9:  #the first doves dunsinened and  Score:  -6.04758167267
# Candidate 10:  #the first doves duneren and kni Score:  -6.06123113632
# Candidate 11:  #the first does duneren knows un Score:  -6.08485746384
# Candidate 12:  #the first doves duneren and mun Score:  -6.13704395294
# Candidate 13:  #the first does dunerems and kni Score:  -6.21546840668
# Candidate 14:  #the first does duneren munders  Score:  -6.21888160706
# Candidate 15:  #the first doves duneren and kno Score:  -6.30825662613
# Candidate 16:  #the first doves dunerent and kn Score:  -6.41845273972
# Candidate 17:  #the first doves dunerens and kn Score:  -6.49684906006
# Candidate 18:  #the first doves dunness munder  Score:  -6.49923801422
# Candidate 19:  #the first doves dunerent and un Score:  -6.49965715408
#
# Candidate 0:  #the first doves dunners under hi Score:  -5.31175851822
# Candidate 1:  #the first does dunners under him Score:  -5.42511034012
# Candidate 2:  #the first doves under numbers an Score:  -5.54695510864
# Candidate 3:  #the first doves dunerement and u Score:  -5.64843177795
# Candidate 4:  #the first does dungeons run and  Score:  -5.79250431061
# Candidate 5:  #the first doves underneath none  Score:  -5.86193656921
# Candidate 6:  #the first doves dunerems and kno Score:  -6.12762784958
# Candidate 7:  #the first doves dunerems and kni Score:  -6.35371732712
# Candidate 8:  #the first doves duneren and know Score:  -6.40689134598
# Candidate 9:  #the first does duneren munders a Score:  -6.41571950912
# Candidate 10:  #the fisher does dunerement and k Score:  -6.48754739761
# Candidate 11:  #the first does duneren knows an  Score:  -6.48900413513
# Candidate 12:  #the first does duneren knows und Score:  -6.55538082123
# Candidate 13:  #the first doves dunness munder a Score:  -6.59148406982
# Candidate 14:  #the first doves dunerement and k Score:  -6.66405487061
# Candidate 15:  #the fisher does dunerement and u Score:  -6.76422262192
# Candidate 16:  #the first doves dunsinened and h Score:  -6.96879768372
# Candidate 17:  #the first does dunerems and knin Score:  -7.03312635422
# Candidate 18:  #the first doves dunerens and kno Score:  -7.10826969147
# Candidate 19:  #the first doves duneren and knig Score:  -7.10949659348
#
# Candidate 0:  #the first doves dunners under him Score:  -5.35973930359
# Candidate 1:  #the first does dunners under him  Score:  -5.42513036728
# Candidate 2:  #the first doves under numbers and Score:  -5.54923629761
# Candidate 3:  #the first doves dunerement and un Score:  -5.64866399765
# Candidate 4:  #the first does dungeons run and t Score:  -5.83479738235
# Candidate 5:  #the first doves underneath none u Score:  -6.27650213242
# Candidate 6:  #the first does duneren munders an Score:  -6.41618156433
# Candidate 7:  #the first doves dunerems and know Score:  -6.50331163406
# Candidate 8:  #the fisher does dunerement and kn Score:  -6.50529146194
# Candidate 9:  #the first does duneren knows unde Score:  -6.56121015549
# Candidate 10:  #the first doves dunness munder an Score:  -6.5916428566
# Candidate 11:  #the first doves duneren and knows Score:  -6.66264724731
# Candidate 12:  #the first doves dunerement and kn Score:  -6.73149013519
# Candidate 13:  #the fisher does dunerement and un Score:  -6.76429748535
# Candidate 14:  #the first doves dunerems and knig Score:  -6.93660736084
# Candidate 15:  #the first does duneren knows an u Score:  -6.97725629807
# Candidate 16:  #the first doves dunsinened and hu Score:  -7.02511358261
# Candidate 17:  #the first does dunerems and knine Score:  -7.03711509705
# Candidate 18:  #the first doves duneren and knigh Score:  -7.11393213272
# Candidate 19:  #the first doves underneath none a Score:  -7.12933111191
#
# Candidate 0:  #the first doves dunners under him  Score:  -5.3597445488
# Candidate 1:  #the first does dunners under him n Score:  -5.46691989899
# Candidate 2:  #the first doves under numbers and  Score:  -5.54923677444
# Candidate 3:  #the first does dungeons run and th Score:  -5.87149524689
# Candidate 4:  #the first doves underneath none un Score:  -6.29562473297
# Candidate 5:  #the first does duneren munders and Score:  -6.48027229309
# Candidate 6:  #the first does duneren knows under Score:  -6.56369447708
# Candidate 7:  #the first doves duneren and knows  Score:  -6.66269111633
# Candidate 8:  #the fisher does dunerement and kno Score:  -6.86446523666
# Candidate 9:  #the first doves dunness munder and Score:  -6.90321922302
# Candidate 10:  #the first doves dunerems and knigh Score:  -6.94067001343
# Candidate 11:  #the first does duneren knows an un Score:  -6.98450899124
# Candidate 12:  #the first does dunerems and knine  Score:  -7.08551359177
# Candidate 13:  #the first doves duneren and knight Score:  -7.11413621902
# Candidate 14:  #the first doves dunerement and kno Score:  -7.15839195251
# Candidate 15:  #the first doves underneath none an Score:  -7.20112419128
# Candidate 16:  #the first doves dunerement and und Score:  -7.29498958588
# Candidate 17:  #the first doves dunerems and know  Score:  -7.30135965347
# Candidate 18:  #the first doves dunerement and unm Score:  -7.47265148163
# Candidate 19:  #the first doves dunerems and knows Score:  -7.49051427841
#
# Candidate 0:  #the first doves dunners under him n Score:  -5.45214366913
# Candidate 1:  #the first does dunners under him no Score:  -5.53295850754
# Candidate 2:  #the first doves under numbers and t Score:  -5.60752725601
# Candidate 3:  #the first does dungeons run and the Score:  -5.87150144577
# Candidate 4:  #the first does duneren munders and  Score:  -6.48027229309
# Candidate 5:  #the first does duneren knows under  Score:  -6.56369972229
# Candidate 6:  #the first doves dunness munder and  Score:  -6.90321922302
# Candidate 7:  #the first doves dunerems and knight Score:  -6.94086647034
# Candidate 8:  #the fisher does dunerement and know Score:  -6.99959754944
# Candidate 9:  #the first doves underneath none und Score:  -7.12285423279
# Candidate 10:  #the first doves duneren and knight  Score:  -7.20423030853
# Candidate 11:  #the first doves underneath none and Score:  -7.21448802948
# Candidate 12:  #the first doves duneren and knows i Score:  -7.24853515625
# Candidate 13:  #the first doves dunerement and know Score:  -7.28101730347
# Candidate 14:  #the first doves dunerement and unde Score:  -7.31409263611
# Candidate 15:  #the first doves dunerems and knows  Score:  -7.49055194855
# Candidate 16:  #the first doves underneath none unt Score:  -7.50724840164
# Candidate 17:  #the first doves dunerement and unme Score:  -7.77039432526
# Candidate 18:  #the first doves duneren and knows u Score:  -7.79673290253
# Candidate 19:  #the first does dunerems and knine u Score:  -7.81745481491
#
# Candidate 0:  #the first doves dunners under him no Score:  -5.50542402267
# Candidate 1:  #the first doves under numbers and th Score:  -5.60761260986
# Candidate 2:  #the first does dunners under him not Score:  -6.41359233856
# Candidate 3:  #the first does dungeons run and the  Score:  -6.49900531769
# Candidate 4:  #the first does duneren munders and t Score:  -6.51569366455
# Candidate 5:  #the first does duneren knows under t Score:  -6.8000535965
# Candidate 6:  #the first doves dunness munder and t Score:  -6.92183923721
# Candidate 7:  #the first doves dunerems and knight  Score:  -6.97000026703
# Candidate 8:  #the first does dunners under him non Score:  -6.9703245163
# Candidate 9:  #the first does dunners under him no  Score:  -7.01415061951
# Candidate 10:  #the first does dungeons run and they Score:  -7.0787820816
# Candidate 11:  #the first doves underneath none unde Score:  -7.12531137466
# Candidate 12:  #the first doves underneath none and  Score:  -7.21448850632
# Candidate 13:  #the first doves dunerement and under Score:  -7.31439161301
# Candidate 14:  #the fisher does dunerement and know  Score:  -7.49524831772
# Candidate 15:  #the first doves dunerement and know  Score:  -7.56474256516
# Candidate 16:  #the first doves underneath none unto Score:  -7.930788517
# Candidate 17:  #the first doves duneren and knows i  Score:  -7.9362821579
# Candidate 18:  #the first does dunners under him nor Score:  -7.97495746613
# Candidate 19:  #the fisher does dunerement and knows Score:  -8.02115249634
#
# Candidate 0:  #the first doves under numbers and the Score:  -5.60766029358
# Candidate 1:  #the first does dunners under him not  Score:  -6.41959190369
# Candidate 2:  #the first does duneren munders and th Score:  -6.51571559906
# Candidate 3:  #the first doves dunners under him no  Score:  -6.69500923157
# Candidate 4:  #the first does dungeons run and the q Score:  -6.78720426559
# Candidate 5:  #the first does duneren knows under th Score:  -6.80008220673
# Candidate 6:  #the first doves dunners under him nor Score:  -6.86962127686
# Candidate 7:  #the first doves dunness munder and th Score:  -6.92249298096
# Candidate 8:  #the first does dunners under him none Score:  -6.98240089417
# Candidate 9:  #the first doves dunners under him not Score:  -7.01271533966
# Candidate 10:  #the first does dungeons run and they  Score:  -7.07880306244
# Candidate 11:  #the first doves underneath none under Score:  -7.13039016724
# Candidate 12:  #the first doves dunners under him non Score:  -7.20818519592
# Candidate 13:  #the first doves underneath none and t Score:  -7.22921037674
# Candidate 14:  #the first doves dunerement and under  Score:  -7.31589269638
# Candidate 15:  #the first doves dunerems and knight u Score:  -7.69759702682
# Candidate 16:  #the first doves dunerement and know t Score:  -7.8768696785
# Candidate 17:  #the first doves underneath none unto  Score:  -7.93079376221
# Candidate 18:  #the first does dunners under him nor  Score:  -7.97573471069
# Candidate 19:  #the fisher does dunerement and know t Score:  -7.99100446701
#
# Candidate 0:  #the first doves under numbers and the  Score:  -5.61852741241
# Candidate 1:  #the first does duneren munders and the Score:  -6.51571750641
# Candidate 2:  #the first does dungeons run and the qu Score:  -6.78720569611
# Candidate 3:  #the first does duneren knows under the Score:  -6.80009126663
# Candidate 4:  #the first doves dunners under him nor  Score:  -6.87034416199
# Candidate 5:  #the first doves dunness munder and the Score:  -6.92249488831
# Candidate 6:  #the first does dunners under him none  Score:  -6.9824090004
# Candidate 7:  #the first does dunners under him not f Score:  -7.00202941895
# Candidate 8:  #the first doves dunners under him not  Score:  -7.0195441246
# Candidate 9:  #the first doves underneath none under  Score:  -7.13049030304
# Candidate 10:  #the first doves underneath none and th Score:  -7.22935247421
# Candidate 11:  #the first doves dunners under him none Score:  -7.23813343048
# Candidate 12:  #the first doves dunerement and under t Score:  -7.34088420868
# Candidate 13:  #the first doves dunners under him no f Score:  -7.61995887756
# Candidate 14:  #the first doves dunners under him no b Score:  -7.80427360535
# Candidate 15:  #the first doves dunerement and know th Score:  -7.87693691254
# Candidate 16:  #the first doves dunerems and knight up Score:  -7.94053983688
# Candidate 17:  #the first does dunners under him not t Score:  -7.95543479919
# Candidate 18:  #the fisher does dunerement and know th Score:  -7.99106931686
# Candidate 19:  #the first doves underneath none unto t Score:  -7.99635362625
#
# Candidate 0:  #the first doves under numbers and the q Score:  -5.77526521683
# Candidate 1:  #the first does duneren munders and the  Score:  -6.52048206329
# Candidate 2:  #the first does dungeons run and the que Score:  -6.78914785385
# Candidate 3:  #the first does duneren knows under the  Score:  -6.80311536789
# Candidate 4:  #the first doves dunness munder and the  Score:  -6.99588155746
# Candidate 5:  #the first doves dunners under him nor t Score:  -7.05535078049
# Candidate 6:  #the first doves underneath none under t Score:  -7.1592669487
# Candidate 7:  #the first does dunners under him not fu Score:  -7.18408203125
# Candidate 8:  #the first doves underneath none and the Score:  -7.22946596146
# Candidate 9:  #the first doves dunners under him none  Score:  -7.23814105988
# Candidate 10:  #the first doves dunerement and under th Score:  -7.34088563919
# Candidate 11:  #the first does dunners under him none f Score:  -7.39295148849
# Candidate 12:  #the first doves dunners under him not f Score:  -7.40527963638
# Candidate 13:  #the first doves dunners under him no fu Score:  -7.72937059402
# Candidate 14:  #the first doves dunerement and know the Score:  -7.876994133
# Candidate 15:  #the first doves under numbers and the n Score:  -7.89617109299
# Candidate 16:  #the first doves dunerems and knight upo Score:  -7.95635986328
# Candidate 17:  #the fisher does dunerement and know the Score:  -7.99118804932
# Candidate 18:  #the first doves underneath none unto th Score:  -7.99635410309
# Candidate 19:  #the first doves dunners under him no be Score:  -8.26625823975
#
# Candidate 0:  #the first doves under numbers and the qu Score:  -5.77526569366
# Candidate 1:  #the first does dungeons run and the quee Score:  -6.79420280457
# Candidate 2:  #the first does duneren knows under the q Score:  -6.92789697647
# Candidate 3:  #the first does duneren munders and the n Score:  -7.02284955978
# Candidate 4:  #the first doves underneath none under th Score:  -7.15926790237
# Candidate 5:  #the first does dunners under him not fur Score:  -7.1849064827
# Candidate 6:  #the first doves underneath none and the  Score:  -7.25221252441
# Candidate 7:  #the first doves dunness munder and the q Score:  -7.28888940811
# Candidate 8:  #the first doves dunerement and under the Score:  -7.3409113884
# Candidate 9:  #the first doves dunners under him none f Score:  -7.45202732086
# Candidate 10:  #the first does dunners under him none fu Score:  -7.5537776947
# Candidate 11:  #the first does duneren munders and the q Score:  -7.57452344894
# Candidate 12:  #the first doves dunners under him not fu Score:  -7.70859336853
# Candidate 13:  #the first doves dunners under him no fur Score:  -7.7306394577
# Candidate 14:  #the first doves dunners under him nor th Score:  -7.75797224045
# Candidate 15:  #the first doves dunerement and know the  Score:  -7.88957881927
# Candidate 16:  #the first doves dunerems and knight upon Score:  -7.95639753342
# Candidate 17:  #the first doves underneath none unto the Score:  -7.99637746811
# Candidate 18:  #the fisher does dunerement and know the  Score:  -8.00248908997
# Candidate 19:  #the first doves under numbers and the nu Score:  -8.19583415985
#
# ...
#
# Candidate 0:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the queen and  Score:  -133.979263306
# Candidate 1:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the queen to piece and come ._ and the benefit of the quiet and the re Score:  -134.233932495
# Candidate 2:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the quiet and  Score:  -134.281814575
# Candidate 3:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the queen to piece and come ._ and the benefit of the quiet ._ and the Score:  -134.580535889
# Candidate 4:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the queen to piece and come ._ and the benefit of the quiet ._here are Score:  -134.671600342
# Candidate 5:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are coming ._ and the better come ._ and th Score:  -134.911239624
# Candidate 6:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the queen to piece and come ._ and the benefit of the quiet and the qu Score:  -135.005950928
# Candidate 7:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the best and c Score:  -135.015289307
# Candidate 8:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the benefit ._ Score:  -135.106231689
# Candidate 9:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the queen to piece and come ._ and the benefit of the quiet and the ro Score:  -135.14465332
# Candidate 10:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the best ._ an Score:  -135.152603149
# Candidate 11:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the benefit of Score:  -135.201278687
# Candidate 12:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the queen ._ a Score:  -135.21105957
# Candidate 13:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the queen to piece and come ._ and the benefit of the ring ._ere all t Score:  -135.23916626
# Candidate 14:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come ._ bid the renown ._ and the quiet and the queen ._ are come but the ring ._ and the queen Score:  -135.326980591
# Candidate 15:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the queen to p Score:  -135.328781128
# Candidate 16:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come ._ bid the renown ._ and the quiet and the queen ._ are come but the ring ._ and the best  Score:  -135.417724609
# Candidate 17:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come ._ bid the renown ._ and the quiet and the queen ._ are come but the ring ._ and the quiet Score:  -135.470474243
# Candidate 18:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the better and Score:  -135.534179688
# Candidate 19:  #the first doves under numbers and the queen for their officers number would confess the benefit of their henry and the punishment from the people and the queen and the punishment with the poor heart between him and the quiet friend ._ and the queen to publish and receive ._ fine ._ the bottom and the quiet and the queen ._ all the question comes ._ fine ._ and the monument ._ are chief ._ and the benefit of the ring ._ere all the punishment ._ and they are come but the ring ._ and the quiet and the queen ._ are come but the ring ._ and the queen to b Score:  -135.839080811
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-2d663a15276b> in <module>()
#      47 fragment_enc = utils.sentence_encode('#', chars)
#      48
# ---> 49 sentence_predicted = beam_search(shakespeare_autoencoder, sentence_enc, fragment_enc, beam_width=20, num_candidates=5)
#
# <ipython-input-26-2d663a15276b> in beam_search(model, sentence_enc, start_frag_enc, beam_width, num_candidates)
#      16         score_matrix = -np.inf * np.ones((num_chars, beam_width))
#      17         for i, candidate in candidates.items():
# ---> 18             p = model.predict([sentence_enc, candidate])[0,-1,:]
#      19             score_matrix[:,i] = np.log(p + EPS) + candidate_scores[i]
#      20         new_symbols = (-score_matrix).argsort(axis=None)[:beam_width]
#
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose)
#    1571         f = self.predict_function
#    1572         return self._predict_loop(f, ins,
# -> 1573                                   batch_size=batch_size, verbose=verbose)
#    1574
#    1575     def train_on_batch(self, x, y,
#
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose)
#    1201                 ins_batch = _slice_arrays(ins, batch_ids)
#    1202
# -> 1203             batch_outs = f(ins_batch)
#    1204             if not isinstance(batch_outs, list):
#    1205                 batch_outs = [batch_outs]
#
# /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2101         session = get_session()
#    2102         updated = session.run(self.outputs + [self.updates_op],
# -> 2103                               feed_dict=feed_dict)
#    2104         return updated[:len(self.outputs)]
#    2105
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Out:
# {'loss': [0.15348826182497002]}

# %%
import os 
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'lstm_encoder_decoder.ipynb',
#  'utils.py',
#  'MNIST_Static_HyperNetwork_Example.ipynb',
#  'model_shakespeare.hd5']

# %%
pwd
# Out:
# '/sandbox'
